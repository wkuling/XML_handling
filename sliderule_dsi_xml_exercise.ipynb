# %% [markdown]
# # XML example and exercise
# ****
# + study examples of accessing nodes in XML tree structure
# + work on exercise to be completed and submitted
# ****
# + reference: https://docs.python.org/2.7/library/xml.etree.elementtree.html
# + data source: http://www.dbis.informatik.uni-goettingen.de/Mondial
# ****

# %%
from xml.etree import ElementTree as ET
import pandas as pd
from unidecode import unidecode

# %% [markdown]
# ## XML example
#
# + for details about tree traversal and iterators, see https://docs.python.org/2.7/library/xml.etree.elementtree.html

# %%
document_tree = ET.parse( './data/mondial_database_less.xml' )

# %%
root = document_tree.getroot()
print root.tag
print root.attrib
# Out:
# mondial
# {}

# %%
# print names of all countries
for child in document_tree.getroot():
    print child.find('name').text
# Out:
# Albania
# Greece
# Macedonia
# Serbia
# Montenegro
# Kosovo
# Andorra

# %%
for child in document_tree.getroot():
    print child.attrib
# Out:
# {'memberships': 'org-BSEC org-CEI org-CD org-SELEC org-CE org-EAPC org-EBRD org-EITI org-FAO org-IPU org-IAEA org-IBRD org-ICC org-ICAO org-ICCt org-Interpol org-IDA org-IFRCS org-IFC org-IFAD org-ILO org-IMO org-IMF org-IOC org-IOM org-ISO org-OIF org-ITU org-ITUC org-IDB org-MIGA org-NATO org-OSCE org-OPCW org-OAS org-OIC org-PCA org-UN org-UNCTAD org-UNESCO org-UNIDO org-UPU org-WCO org-WFTU org-WHO org-WIPO org-WMO org-UNWTO org-WTO', 'area': '28750', 'car_code': 'AL', 'capital': 'cty-Albania-Tirane'}
# {'memberships': 'org-AG org-BIS org-BSEC org-CD org-SELEC org-CE org-EMU org-EAPC org-EBRD org-ECB org-EIB org-CERN org-ESA org-EU org-FATF org-FAO org-IGAD org-IPU org-IAEA org-IBRD org-ICC org-ICAO org-ICJ org-ICCt org-Interpol org-IDA org-IEA org-IFRCS org-IFC org-IFAD org-IHO org-ILO org-IMO org-IMSO org-IMF org-IOC org-IOM org-OIF org-ITSO org-ITU org-ITUC org-MIGA org-NATO org-NEA org-NSG org-OECD org-OSCE org-OPCW org-OAS org-PCA org-UN org-UNCTAD org-UNESCO org-UNHCR org-UNIDO org-UNIFIL org-UPU org-WCO org-WFTU org-WHO org-WIPO org-WMO org-UNWTO org-WTO org-ZC', 'area': '131940', 'car_code': 'GR', 'capital': 'cty-Greece-Athens'}
# {'memberships': 'org-BIS org-CEI org-CD org-SELEC org-CE org-EAPC org-EBRD org-EU org-FAO org-IPU org-IAEA org-IBRD org-ICC org-ICAO org-ICCt org-Interpol org-IDA org-IFRCS org-IFC org-IFAD org-ILO org-IMO org-IMF org-IOC org-IOM org-OIF org-ITU org-ITUC org-MIGA org-OSCE org-OPCW org-OAS org-PFP org-PCA org-UN org-UNCTAD org-UNESCO org-UNHCR org-UNIDO org-UNIFIL org-UPU org-WCO org-WHO org-WIPO org-WMO org-UNWTO org-WTO', 'area': '25333', 'car_code': 'MK', 'capital': 'cty-Macedonia-Skopje'}
# {'memberships': 'org-BIS org-BSEC org-CEI org-CD org-SELEC org-CE org-EAPC org-EBRD org-EU org-FAO org-G-9 org-IPU org-IAEA org-IBRD org-ICC org-ICAO org-ICCt org-Interpol org-IDA org-IFRCS org-IFC org-IHO org-ILO org-IMO org-IMSO org-IMF org-IOC org-IOM org-OIF org-ITSO org-ITU org-ITUC org-MIGA org-NAM org-NSG org-OSCE org-OPCW org-OAS org-PFP org-PCA org-UN org-UNCTAD org-UNESCO org-UNHCR org-UNIDO org-UNIFIL org-UNMIL org-UNOCI org-MONUSCO org-UNFICYP org-UNTSO org-UPU org-WCO org-WHO org-WIPO org-WMO org-UNWTO org-WTO', 'area': '77474', 'car_code': 'SRB', 'capital': 'city-Belgrade-SRB-SRB'}
# {'memberships': 'org-CEI org-CD org-SELEC org-CE org-EAPC org-EBRD org-EU org-FAO org-IPU org-IAEA org-IBRD org-ICC org-ICAO org-ICCt org-Interpol org-IDA org-IFRCS org-IFC org-IHO org-ILO org-IMO org-IMSO org-IMF org-IOC org-IOM org-ISO org-OIF org-ITSO org-ITU org-ITUC org-MIGA org-NAM org-OSCE org-OPCW org-PFP org-PCA org-UN org-UNCTAD org-UNESCO org-UNHCR org-UNIDO org-UNMIL org-UPU org-WCO org-WHO org-WIPO org-WMO org-UNWTO org-WTO', 'area': '14026', 'car_code': 'MNE', 'capital': 'city-Podgorica-MNE-MNE'}
# {'memberships': 'org-CD org-EBRD org-IBRD org-IDA org-IFC org-IMF org-ITUC', 'area': '10887', 'car_code': 'KOS', 'capital': 'city-Pristina-KOS-KOS'}
# {'memberships': 'org-CE org-FAO org-IPU org-ICC org-ICAO org-ICCt org-Interpol org-IFRCS org-IOC org-OIF org-ITU org-OSCE org-OPCW org-UN org-UNCTAD org-UNESCO org-WCO org-WHO org-WIPO org-UNWTO org-WTO', 'area': '450', 'car_code': 'AND', 'capital': 'cty-Andorra-Andorra-la-Vella'}

# %%
# print names of all countries and their cities
for element in document_tree.iterfind('country'):
    print '* ' + element.find('name').text + ':',
    capitals_string = ''
    for subelement in element.getiterator('city'):
        capitals_string += subelement.find('name').text + ', '
    print capitals_string[:-2]
# Out:
# * Albania: Tirana, Shkodër, Durrës, Vlorë, Elbasan, Korçë
# * Greece: Komotini, Kavala, Athina, Peiraias, Peristeri, Acharnes, Patra, Kozani, Kerkyra, Ioannina, Thessaloniki, Iraklio, Chania, Ermoupoli, Rhodes, Tripoli, Lamia, Chalkida, Larissa, Volos, Mytilini, Karyes
# * Macedonia: Skopje, Kumanovo
# * Serbia: Beograd, Novi Sad, Niš
# * Montenegro: Podgorica
# * Kosovo: Prishtine
# * Andorra: Andorra la Vella

# %% [markdown]
# ****
# ## XML exercise
#
# Using data in 'data/mondial_database.xml', the examples above, and refering to https://docs.python.org/2.7/library/xml.etree.elementtree.html, find
#
# 1. 10 countries with the lowest infant mortality rates
# 2. 10 cities with the largest population
# 3. 10 ethnic groups with the largest overall populations (sum of best/latest estimates over all countries)
# 4. name and country of a) longest river, b) largest lake and c) airport at highest elevation

# %%
document = ET.parse( './data/mondial_database.xml' )

# %%
root = document.getroot()

# %%
for child in root:
    for small in child:
        if (small.tag=='name'):
            print small.text
#    for small in child:
#        pass
# Out:
# Albania
# Greece
# Macedonia
# Serbia
# Montenegro
# Kosovo
# Andorra
# France
# Spain
# Austria
# Czech Republic
# Germany
# Hungary
# Italy
# Liechtenstein
# Slovakia
# Slovenia
# Switzerland
# Belarus
# Latvia
# Lithuania
# Poland
# Ukraine
# Russia
# Belgium
# Luxembourg
# Netherlands
# Bosnia and Herzegovina
# Croatia
# Bulgaria
# Romania
# Turkey
# Denmark
# Estonia
# Faroe Islands
# Finland
# Norway
# Sweden
# Monaco
# Gibraltar
# Guernsey
# Holy See
# Ceuta
# Melilla
# Iceland
# Ireland
# San Marino
# Jersey
# Malta
# Isle of Man
# Moldova
# Portugal
# Svalbard
# United Kingdom
# Afghanistan
# China
# Iran
# Pakistan
# Tajikistan
# Turkmenistan
# Uzbekistan
# Armenia
# Georgia
# Azerbaijan
# Bahrain
# Bangladesh
# Myanmar
# India
# Bhutan
# Brunei
# Malaysia
# Laos
# Thailand
# Cambodia
# Vietnam
# Kazakhstan
# North Korea
# Kyrgyzstan
# Hong Kong
# Macao
# Mongolia
# Nepal
# Christmas Island
# Cocos Islands
# Cyprus
# Gaza Strip
# Israel
# Egypt
# Indonesia
# Timor-Leste
# Papua New Guinea
# Iraq
# Jordan
# Kuwait
# Saudi Arabia
# Syria
# Lebanon
# West Bank
# Japan
# South Korea
# Maldives
# Long Beach
# La Guardia
# Lovell Fld
# Shreveport Rgnl
# Adams Fld
# Norman Y Mineta San Jose Intl
# Birmingham Intl
# Bismarck Municipal Airport
# Billings Logan International Airport
# Tulsa Intl
# Tucson Intl
# Reno Tahoe Intl
# Buffalo Niagara Intl
# Hartsfield Jackson Atlanta Intl
# Baton Rouge Metro Ryan Fld
# Austin Bergstrom Intl
# Mc Ghee Tyson
# Baltimore Washington Intl
# Akron Canton Regional Airport
# Lehigh Valley Intl
# Abilene Rgnl
# Alexandria Intl
# Tallahassee Rgnl
# Waco Rgnl
# Albuquerque International Sunport
# San Diego Intl
# San Antonio Intl
# Savannah Hilton Head Intl
# Portland Intl Jetport
# Theodore Francis Green State
# Indianapolis Intl
# Washington Dulles Intl
# George Bush Intcntl Houston
# Wichita Mid Continent
# William P Hobby
# Greater Rochester Intl
# Fort Lauderdale Hollywood Intl
# Eppley Afld
# Portland Intl
# Norfolk Intl
# Chicago Ohare Intl
# Bishop International
# Phoenix Sky Harbor Intl
# Pittsburgh Intl
# Pierre Regional Airport
# Philadelphia Intl
# Helena Rgnl
# Spokane Intl
# Will Rogers World
# Richmond Intl
# John F Kennedy Intl
# Jacksonville Intl
# Jackson Evers Intl
# Santa Fe Muni
# Albert J Ellis
# Metropolitan Oakland Intl
# Juneau Intl
# Ted Stevens Anchorage Intl
# Honolulu Intl
# Hilo Intl
# Lanai
# Molokai
# Kahului
# Carrasco Intl
# Bukhara
# Urgench Airport
# Termez Airport
# Yuzhny
# Nukus Airport
# Fergana Airport
# Samarkand
# Port Vila Bauerfield
# General Manuel Carlos Piar
# General Jose Antonio Anzoategui Intl
# Casique Aramare
# Barinas
# Barquisimeto Intl
# La Chinita Intl
# Arturo Michelena Intl
# Maturin
# Simon Bolivar Intl
# Rach Gia
# Vinh Airport
# Tansonnhat Intl
# Noibai Intl
# Cat Bi International Airport
# Tra Noc Airport
# Nha Trang
# Cyril E King
# Wallis
# Hassan I Airport
# Sanaa Intl
# Hodeidah Intl
# Taiz Intl
# Aden Intl
# Livingstone
# Ndola
# Lusaka Intl
# J M Nkomo Intl
# Harare Intl

# %% [markdown]
# # Excercise 1: find countries with lowest infant mortality rate

# %%
dict1 = {}

for child in root:
    if (child.tag == 'country'):
        for small in child:
            if (small.tag=='name'):
                country_to_add = small.text
                # print country_to_add
            if (small.tag=='infant_mortality'):
                mortality_to_add = small.text
                dict1[country_to_add] = mortality_to_add
#dict1
df = pd.DataFrame(dict1.items(), columns=['Country', 'Infant_mortality'])
df
# Out:
#                       Country Infant_mortality
# 0                      Canada             4.71
# 1       Sao Tome and Principe            49.16
# 2                Turkmenistan            38.13
# 3                Saint Helena            17.63
# 4                   Lithuania                6
# 5                    Cambodia            51.36
# 6                    Ethiopia            55.77
# 7                       Aruba            11.74
# 8                  Micronesia            21.93
# 9                      Belize            20.31
# 10                  Argentina             9.96
# 11                    Bolivia            38.61
# 12                   Cameroon             55.1
# 13               Burkina Faso             76.8
# 14                  Swaziland            54.82
# 15                    Bahrain             9.68
# 16               Saudi Arabia            14.58
# 17             American Samoa             8.92
# 18   Northern Mariana Islands              5.5
# 19                   Slovenia             4.04
# 20                  Guatemala            23.51
# 21     Bosnia and Herzegovina             5.84
# 22                     Guinea            55.24
# 23                    Germany             3.46
# 24                      Spain             3.33
# 25                  Australia             4.43
# 26                    Liberia            69.19
# 27                Netherlands             3.66
# 28                   Paraguay            20.75
# 29                    Jamaica            13.69
# ..                        ...              ...
# 198               Philippines            17.64
# 199                Mauritania            56.06
# 200                Kyrgyzstan            28.71
# 201                   Mayotte            56.29
# 202                Montserrat            13.66
# 203             New Caledonia             5.46
# 204                 Macedonia              7.9
# 205               North Korea             24.5
# 206       Trinidad and Tobago            24.82
# 207                   Lesotho            50.48
# 208                    Latvia             7.91
# 209               South Sudan            68.16
# 210                     Japan             2.13
# 211                     Syria            15.79
# 212                Guadeloupe              8.3
# 213                     Niger            86.27
# 214                  Honduras            18.72
# 215                   Myanmar            44.91
# 216                    Mexico            12.58
# 217                     Egypt            22.41
# 218                 Nicaragua            20.36
# 219                      Cuba              4.7
# 220                    Serbia             6.16
# 221                   Comoros            65.31
# 222            United Kingdom             4.44
# 223                     Congo            59.34
# 224                    Greece             4.78
# 225                 Sri Lanka             9.02
# 226                      Fiji             10.2
# 227                  Botswana             9.38
#
# [228 rows x 2 columns]

# %%
df.sort('Infant_mortality')
# Out:
#                               Country Infant_mortality
# 35                             Monaco             1.81
# 103                           Romania            10.16
# 226                              Fiji             10.2
# 130                            Brunei            10.48
# 157                           Grenada             10.5
# 102                         Mauritius            10.59
# 118                            Panama             10.7
# 72                         Seychelles            10.77
# 45               United Arab Emirates            10.92
# 175                          Barbados            10.93
# 60           Turks and Caicos Islands            10.97
# 68                            Somalia           100.14
# 99                               Mali           104.34
# 126                             Palau            11.46
# 169                          Dominica            11.61
# 7                               Aruba            11.74
# 61                        Saint Lucia            11.75
# 91                              Libya            11.87
# 56                        Afghanistan           117.23
# 89                              Tonga            12.36
# 36                            Bahamas             12.5
# 216                            Mexico            12.58
# 150                           Moldova            12.93
# 51   Saint Vincent and the Grenadines            13.07
# 43                            Albania            13.19
# 85                Antigua and Barbuda            13.29
# 98             British Virgin Islands            13.45
# 202                        Montserrat            13.66
# 29                            Jamaica            13.69
# 109                          Malaysia            13.69
# ..                                ...              ...
# 140                       Puerto Rico             7.73
# 204                         Macedonia              7.9
# 208                            Latvia             7.91
# 163                           Lebanon             7.98
# 162                 Equatorial Guinea            71.12
# 111                        Mozambique            72.42
# 136                             Zaire            73.15
# 146                      Sierra Leone            73.29
# 127                           Nigeria            74.09
# 13                       Burkina Faso             76.8
# 104                            Angola            79.99
# 87                            Ukraine              8.1
# 71                              Nauru             8.21
# 212                        Guadeloupe              8.3
# 174                            Cyprus             8.54
# 120                        Costa Rica              8.7
# 17                     American Samoa             8.92
# 161                           Uruguay             8.97
# 79              Saint Kitts and Nevis             8.98
# 213                             Niger            86.27
# 225                         Sri Lanka             9.02
# 114                      Sint Maarten             9.05
# 227                          Botswana             9.38
# 32                          Greenland             9.42
# 15                            Bahrain             9.68
# 142                          Thailand             9.86
# 10                          Argentina             9.96
# 159                              Chad             90.3
# 81                      Guinea-Bissau            90.92
# 94           Central African Republic            92.86
#
# [228 rows x 2 columns]

# %%
# So I need to convert Infant_mortality to a float object, it seems a string now...
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 228 entries, 0 to 227
# Data columns (total 2 columns):
# Country             228 non-null object
# Infant_mortality    228 non-null object
# dtypes: object(2)
# memory usage: 5.3+ KB

# %%
df['Infant_mortality']=df['Infant_mortality'].astype(float)
df.sort('Infant_mortality').head(10)
# Out:
#             Country  Infant_mortality
# 35           Monaco              1.81
# 210           Japan              2.13
# 73           Norway              2.48
# 66          Bermuda              2.48
# 78        Singapore              2.53
# 108          Sweden              2.60
# 57   Czech Republic              2.63
# 145       Hong Kong              2.73
# 54            Macao              3.13
# 188         Iceland              3.15

# %%
df[df.Country=='Netherlands']
# Out:
#         Country  Infant_mortality
# 27  Netherlands              3.66

# %% [markdown]
# ##2. 10 cities with the largest population

# %%
dict1 = {}

for countries in root:
    if (countries.tag == 'country'):
        # print "Yeah... found a country!"
        for provinces in countries:
            if (provinces.tag =='province'):
                # print "Yeah... found a province!"
                for cities in provinces:
                    if (cities.tag == 'city'):
                        # print "Yeah... found a city!"
                        for specifics in cities:
                            if (specifics.tag=='name'):
                                city_to_add=specifics.text
                                # print city_to_add # just for debugging purposes
                            if (specifics.tag=='population') and (specifics.attrib['year']=='2011'):
                                # print specifics.attrib
                                population_to_add=specifics.text
                                # print population_to_add
                                dict1[unidecode(city_to_add)] = population_to_add
dict1
df_cities = pd.DataFrame(dict1.items(), columns=['City', 'Population'])
df_cities
# Out:
# C:\Users\m01i795\AppData\Local\Continuum\Anaconda\lib\site-packages\IPython\kernel\__main__.py:20: RuntimeWarning: Argument <type 'str'> is not an unicode object. Passing an encoded string will likely have unexpected results.
#                      City Population
# 0                  Szeged     168048
# 1            Dos Hermanas     128433
# 2                  Torino     872367
# 3                  Dundee     147285
# 4                  Ancona     100497
# 5            Khorramshahr     129418
# 6                 Ipswich     144957
# 7                Rochdale     107926
# 8                  Lleida     137283
# 9                  Meerut    1305429
# 10                   Khoy     200958
# 11              Liverpool     552267
# 12           High Wycombe     120256
# 13                 Verona     252520
# 14       Pietermaritzburg     618536
# 15                Trencin      55877
# 16                 Mataro     123367
# 17               Montreal    1649519
# 18                Bologna     371337
# 19             Valladolid     311682
# 20                   Caen     108793
# 21                Bergamo     115349
# 22              Kecskemet     111411
# 23            Yellowknife      19234
# 24               Solihull     123187
# 25               Terrassa     214406
# 26                Brescia     189902
# 27                 Exeter     113507
# 28                Pitesti     155383
# 29                 Kanpur    2765348
# ..                    ...        ...
# 551             Neyshabur     239185
# 552                  Kota    1001694
# 553                 Parla     122045
# 554              Jabalpur    1055525
# 555               Mulheim     166865
# 556               Munchen    1348335
# 557               Szolnok      72953
# 558            Gold Coast     576747
# 559            Mymensingh     258040
# 560               Larissa     162591
# 561             Pardubice      90844
# 562                  Zlin      77137
# 563              Worthing     109120
# 564                Murcia     437667
# 565  Freiburg im Breisgau     209628
# 566            Birkenhead     142968
# 567             Melbourne    4169103
# 568              Plymouth     234982
# 569            Oberhausen     210216
# 570                 Derby     255394
# 571               Iqaluit       6699
# 572                 Terni     109193
# 573         Khomeinishahr     244696
# 574               Leipzig     502979
# 575        Gonbad-e-Kavus     144546
# 576            Sunderland     174286
# 577             Bielefeld     326870
# 578             Worcester     100153
# 579               Cardiff     335145
# 580               Swindon     182441
#
# [581 rows x 2 columns]

# %%
df_cities['Population']=df_cities['Population'].astype(int)
df_cities=df_cities.sort('Population', ascending=False)

# %%
df_cities.head(10)
# Out:
#           City  Population
# 267     Mumbai    12442373
# 169      Delhi    11034555
# 329  Bangalore     8443675
# 353     Tehran     8154051
# 137      Dhaka     7423137
# 507  Hyderabad     6731790
# 460  Ahmadabad     5577940
# 89      Luanda     5000000
# 64     Chennai     4646732
# 266     Sydney     4605992

# %% [markdown]
# # 3: 10 ethnic groups with the largest overall populations (sum of best/latest estimates over all countries)

# %%
# Idea: store size per ethnicity group in dictionary > convert to Pandas object > use value_counts
# Idea 2: overwrite value of population every time > storing the latest/best estimate for population size

# %%
dict1 = {}

for countries in root:
    if (countries.tag == 'country'):
        # print "Yeah... found a country!"
        for stuff in countries:
            if (stuff.tag =='population'):
                # print "Yeah... found a population!"
                population_to_use = float(stuff.text)
            if (stuff.tag =='ethnicgroup'):
                percentage = float(stuff.attrib['percentage'])
                ethnicgroup = stuff.text
                dict1[unidecode(ethnicgroup)]=int(percentage*population_to_use)
dict1
# Out:
# C:\Users\m01i795\AppData\Local\Continuum\Anaconda\lib\site-packages\IPython\kernel\__main__.py:13: RuntimeWarning: Argument <type 'str'> is not an unicode object. Passing an encoded string will likely have unexpected results.
# {'Acholi': 139427252,
#  'Afar': 143345677,
#  'African': 115735356,
#  'African descent': 283150,
#  'African-white-Indian': 35306190,
#  'Afro-Asian': 271369770,
#  'Afro-Chinese': 3237579,
#  'Afro-East Indian': 8093949,
#  'Afro-European': 40739543,
#  'Albanian': 159516224,
#  'Alemannic': 3480420,
#  'Americo-Liberians': 19789950,
#  'Amerindian': 362087475,
#  'Amhara': 2268234550L,
#  'Andorran': 2577795,
#  'Arab': 34856813,
#  'Arab Iranian': 194155351,
#  'Arab-Berber': 1076309892,
#  'Arabic': 104365789,
#  'Armenian': 17364368,
#  'Asian': 5751976,
#  'Assyrian': 166652560,
#  'Austrian': 774328044,
#  'Aymara': 250681550,
#  'Azerbaijani': 1803592056,
#  'Azeri': 847698900,
#  'Baganda': 592565821,
#  'Bagisu': 174284065,
#  'Bahraini': 77779548,
#  'Bakongo': 316982913,
#  'Baloch': 150299338,
#  'Banda': 117447867,
#  'Bantu': 4268247685L,
#  'Baoule': 521440613,
#  'Bashkir': 172400317,
#  'Basogo': 278854504,
#  'Basques Bretons': 631200,
#  'Batobo': 104570439,
#  'Batswana': 193631660,
#  'Baya': 147897314,
#  'Beja': 213912012,
#  'Belorussian': 1553346,
#  'Bengali': 14677691672L,
#  'Berber Arab': 585939364,
#  'Beri Beri': 73696440,
#  'Bete': 408083958,
#  'Bhote': 36650200,
#  'Bilen': 11482318,
#  'Black': 29806312,
#  'Black Maur': 141494720,
#  'Borneo indigenous': 303224031,
#  'Bosniak': 140669176,
#  'Bounty': 6600,
#  'British Isles': 984432512,
#  'Bulgarian': 6763127,
#  'Bunyoro': 104570439,
#  'Burman': 3496520560L,
#  'Byelorussian': 19266894,
#  'Cameroon Highlanders': 601589100,
#  'Carib Indians': 7073900,
#  'Caribbean': 13474544,
#  'Caucasian': 96989,
#  'Celt': 31845200,
#  'Chamorro': 5912181,
#  'Chinese': 141575,
#  'Christian': 196963,
#  'Chuvash': 158033624,
#  'Circassian': 6249000,
#  'Colored': 445226816,
#  'Creole': 33401457,
#  'Crimean Tatar': 22816818,
#  'Croat': 384438835,
#  'Czech': 5397036,
#  'Dagestani': 20584300,
#  'Danish': 789180,
#  'Diola': 121578435,
#  'Djerma': 377051554,
#  'Dravidian': 30271374425L,
#  'Dungan': 6354260,
#  'Dutch': 1359244706,
#  'East Indian': 32532954,
#  'Eastern Hamitic': 8283037653L,
#  'Eastern Nigritic': 135842700,
#  'Emiri': 160389203,
#  'English': 5359232674L,
#  'Equatorial Bantu': 368715900,
#  'Estonian': 1636520,
#  'Euro-African': 4740143,
#  'Euronesians': 1314740,
#  'European': 18735600,
#  'European Lebanese': 13508715,
#  'European Syrian-Lebanese': 6191155,
#  'European/Caribbean Amerindian': 8118720,
#  'Europeans': 541638,
#  'Fijian': 42167391,
#  'Filipino': 4191115,
#  'Finn': 47779465,
#  'Fleming': 643774132,
#  'Franco-Mauritian': 2474182,
#  'French': 945196,
#  'Fula': 145679009,
#  'Fulani': 229648155,
#  'Gagauz': 15661980,
#  'Garifuna': 1909123,
#  'Georgian': 375742440,
#  'German': 18881762,
#  'Gilaki Mazandarani': 601197352,
#  'Gourmantche': 20566448,
#  'Greek': 64711339,
#  'Greenlander': 4847820,
#  'Gurage': 210802467,
#  'Gypsy': 5561443,
#  'Hadiya': 143345677,
#  'Han Chinese': 124505880000L,
#  'Hausa': 959767592,
#  'Hazara': 494438900,
#  'Hindustani': 20040606,
#  'Hungarian': 132802830,
#  'Hutu': 841277840,
#  'Indian': 1896057,
#  'Indo-Aryan': 87181558344L,
#  'Indo-Mauritian': 84122188,
#  'Indonesian': 613950,
#  'Inuit': 70316608,
#  'Iranian': 16994350,
#  'Irish': 401013224,
#  'Italian': 4170180,
#  'Iteso': 278854504,
#  'Japanese': 12653421200L,
#  'Javanese': 8287061,
#  'Jewish': 10982754,
#  'Kalenjin': 490910328,
#  'Kamba': 450001134,
#  'Karakalpak': 69423175,
#  'Karamojong': 418281756,
#  'Karen': 359935940,
#  'Kazak': 13773425,
#  'Kazakh': 1083126580,
#  'Kgalagadi': 8152912,
#  'Khmer': 133159350,
#  'Kikuyu': 900002268,
#  'Kimbundu': 609582525,
#  'Kirdi': 213467100,
#  'Kisii': 245455164,
#  'Kunama': 11482318,
#  'Kurd': 526047683,
#  'Kurdish': 499957680,
#  'Kuwaiti': 134621100,
#  'Kyrgyz': 374901340,
#  'Langi': 209140878,
#  'Lao Loum': 442981376,
#  'Lao Soung Hmong Yao': 58629888,
#  'Lao Theung': 143317504,
#  'Latvian': 130530922,
#  'Lithuanian': 250262040,
#  'Lugbara': 139427252,
#  'Luhya': 572728716,
#  'Luo': 531819522,
#  'Lur': 150299338,
#  'Luxembourgish': 33118224,
#  'MBaka': 17399684,
#  'Macedonian': 18211380,
#  'Madurese': 1890933435,
#  'Malay': 75642830,
#  'Malinke': 318869160,
#  'Mande': 699298050,
#  'Mandingo': 121578435,
#  'Mandjia': 91348341,
#  'Mangbetu-Azande': 2798602245L,
#  'Maori': 31391155,
#  'Maur': 106121040,
#  'Maya': 3317492,
#  'Mboum': 17399684,
#  'Mediterranean Nordic': 4681591600L,
#  'Melanesian': 22212106,
#  'Meru': 245455164,
#  'Mestizo': 941427435,
#  'Micronesian': 789670,
#  'Mixed': 2227640,
#  'Moldavian/Romanian': 278356106,
#  'Moldovan': 22816818,
#  'Mon': 102838840,
#  'Monegasque': 795852,
#  'Mong': 106527480,
#  'Mongol': 261419606,
#  'Montenegrin': 26661247,
#  'Moravian': 39080191,
#  'Moroccan': 33686362,
#  'Mossi': 415747104,
#  'Mulatto': 7806589637L,
#  'Muong': 133159350,
#  'Muslim': 3861550,
#  'Nauruan': 581450,
#  'Nepalese': 25655140,
#  'None': 92326,
#  'Norman-French': 9785700,
#  'Northern Irish': 185906396,
#  'Northwestern Bantu': 155248800,
#  'Norwegian': 103708,
#  'Nung': 97650190,
#  'Oromo': 2909074051L,
#  'Ovimbundu': 902182137,
#  'Pacific Islander': 1955952,
#  'Pakistani': 30589830,
#  'Palestinian Arab': 231597473,
#  'Pashtun': 988877800,
#  'Persian': 3832633119L,
#  'Peuhl': 425158880,
#  'Polish': 13690091,
#  'Polynesian': 1219700,
#  'Portuguese': 1657509,
#  'Quechua': 300817860,
#  'Rakhine': 205677680,
#  'Rashaida': 11482318,
#  'Roma': 50304102,
#  'Romanian': 1792838213,
#  'Romansch': 8139631,
#  'Russian': 72207500,
#  'Russian Ukrainian': 82929,
#  'Ruthenian': 1619110,
#  'Rwanda': 209140878,
#  'Saho': 22964636,
#  'Sami': 7576912,
#  'Samoan': 17392132,
#  'Sara': 43499210,
#  'Scandinavian': 4819700,
#  'Scottish': 551308624,
#  'Senoufou': 340069965,
#  'Serb': 19307754,
#  'Serbian': 8669360,
#  'Serbs': 16999518,
#  'Serer': 229648155,
#  'Seychellois': 9094500,
#  'Shan': 462774780,
#  'Sidama': 337283948,
#  'Sinhalese': 1499515502,
#  'Sino-Mauritian': 3711273,
#  'Slovak': 462525985,
#  'Slovene': 2145306,
#  'Somali': 819074705,
#  'Songhai': 83915766,
#  'Sotho': 200289423,
#  'Soussou': 212579440,
#  'South Asian': 422076850,
#  'Spanish': 3358945,
#  'Sundanese': 3529742412L,
#  'Surinamese': 33686362,
#  'Swede': 793139119,
#  'Taiwanese': 1958529048,
#  'Tajik': 138846350,
#  'Tamil': 364747014,
#  'Tatar': 22314810,
#  'Tay': 168668510,
#  'Thai': 159791220,
#  'Tigraway': 514358020,
#  'Tigre': 172234770,
#  'Tigrinya': 315763745,
#  'Tongan': 222076,
#  'Toucouleur': 121578435,
#  'Tuareg': 137109656,
#  'Turkish': 15127326,
#  'Turkmen': 428569575,
#  'Tutsi': 199803487,
#  'Twa': 10515973,
#  'Uighur': 5776600,
#  'Ukrainian': 5776600,
#  'Uzbek': 79717080,
#  'Vedda': 20263723,
#  'Viet/Kinh': 7607837530L,
#  'Vietnamese': 343812,
#  'Vietnamese/Chinese': 6514432,
#  'Voltaic': 167831532,
#  'Wallisian': 2210220,
#  'Walloon': 344086174,
#  'Welaita': 193938270,
#  'Welsh': 314117704,
#  'White': 141575,
#  'Wolof': 486313740,
#  'Yezidi': 3934942,
#  'black-Amerindian': 142985361}

# %%
df_ethnic = pd.DataFrame(dict1.items(), columns=['Ethnicgroup', 'Size'])
df_ethnic.sort(['Size'], ascending=False).head(10)
# Out:
#               Ethnicgroup          Size
# 92            Han Chinese  124505880000
# 102            Indo-Aryan   87181558344
# 177             Dravidian   30271374425
# 182               Bengali   14677691672
# 269              Japanese   12653421200
# 84        Eastern Hamitic    8283037653
# 250               Mulatto    7806589637
# 265             Viet/Kinh    7607837530
# 149               English    5359232674
# 168  Mediterranean Nordic    4681591600

# %% [markdown]
# # Excercise 4: name and country of a) longest river, b) largest lake and c) airport at highest elevation

# %%
dict_river = {}

for countries in root:
    if (countries.tag == 'river'):
        country_id=countries.attrib['country']
        river_id =countries.attrib['id']
        for stuff in countries:
            if (stuff.tag=='length'):
                dict_river[(country_id, river_id)]=float(stuff.text)

# %%
dict_river
# Out:
# {('A', 'river-Enns'): 254.0,
#  ('A D', 'river-Salzach'): 225.0,
#  ('A H', 'river-Raab'): 250.0,
#  ('A H SLO HR', 'river-Mur'): 453.0,
#  ('AFG TAD', 'river-Pjandsh'): 1141.0,
#  ('AL', 'river-Drin'): 152.0,
#  ('AL KOS', 'river-Weisser_Drin'): 175.0,
#  ('AL MK', 'river-Schwarzer_Drin'): 133.0,
#  ('AL MNE', 'river-Buna'): 44.0,
#  ('ANG NAM RB', 'Okavango'): 1700.0,
#  ('ANG NAM RB Z ZW MOC', 'river-Sambesi'): 2574.0,
#  ('ANG ZRE', 'river-Kasai'): 1983.0,
#  ('ANG ZRE', 'river-Kuango'): 1100.0,
#  ('ANG ZRE', 'river-Kwilu'): 970.0,
#  ('AUS', 'river-DarlingRiver'): 2739.0,
#  ('AUS', 'river-Eucumbene'): 83.0,
#  ('AUS', 'river-MurrayRiver'): 2589.0,
#  ('AUS', 'river-MurrumbidgeeRiver'): 1579.0,
#  ('AUS', 'river-SnowyRiver'): 403.0,
#  ('BIH SRB', 'river-Drina'): 346.0,
#  ('BOL', 'river-Desaguadero'): 383.0,
#  ('BOL', 'river-RioMamore'): 1931.0,
#  ('BR', 'river-RioSaoFrancisco'): 2830.0,
#  ('BR', 'river-Tocantins'): 2640.0,
#  ('BR BOL', 'river-RioMadeira'): 1450.0,
#  ('BR CO', 'river-RioNegro'): 2253.0,
#  ('BR ROU RA', 'river-Uruguay'): 1790.0,
#  ('BY LV R', 'river-Westliche_Dwina'): 1020.0,
#  ('BY UA', 'river-Prypjat'): 775.0,
#  ('BY UA R', 'river-Dnepr'): 2201.0,
#  ('CAM', 'river-Sanaga'): 918.0,
#  ('CAM RCA RCB', 'river-Sanga'): 530.0,
#  ('CDN', 'river-Mackenzie'): 1903.0,
#  ('CDN', 'river-Manicouagan'): 560.0,
#  ('CDN', 'river-NelsonRiver'): 664.0,
#  ('CDN', 'river-Richelieu'): 124.0,
#  ('CDN', 'river-SaskatchewanRiver'): 1392.0,
#  ('CDN USA', 'river-Columbia_River'): 1953.0,
#  ('CDN USA', 'river-DetroitRiver'): 200.0,
#  ('CDN USA', 'river-NiagaraRiver'): 58.0,
#  ('CDN USA', 'river-Saint-Marys-River'): 120.0,
#  ('CDN USA', 'river-StLorenzstrom'): 1197.0,
#  ('CDN USA', 'river-Yukon'): 3185.0,
#  ('CH', 'river-Aare'): 288.0,
#  ('CH', 'river-Limmat'): 36.3,
#  ('CH', 'river-Reuss'): 164.0,
#  ('CH A D', 'river-Inn'): 517.0,
#  ('CH I', 'river-Ticino'): 248.0,
#  ('CN', 'river-Hwangho'): 4845.0,
#  ('CN', 'river-Jangtse'): 6380.0,
#  ('CN', 'river-Tarim'): 3260.0,
#  ('CN IND BD', 'river-Brahmaputra'): 2896.0,
#  ('CN KAZ', 'river-Ili'): 1001.0,
#  ('CN LAO THA K VN', 'river-Mekong'): 4350.0,
#  ('CO', 'river-RioMagdalena'): 1538.0,
#  ('CO BR PE', 'river-Amazonas'): 6448.0,
#  ('CZ', 'river-Moldau'): 440.0,
#  ('CZ SK A', 'river-March'): 358.0,
#  ('D', 'river-Aller'): 211.0,
#  ('D', 'river-Alz'): 150.0,
#  ('D', 'river-Ammer'): 168.0,
#  ('D', 'river-Breg'): 45.9,
#  ('D', 'river-Brigach'): 43.0,
#  ('D', 'river-Fulda'): 221.0,
#  ('D', 'river-Leine'): 281.0,
#  ('D', 'river-Main'): 524.0,
#  ('D', 'river-Neckar'): 367.0,
#  ('D', 'river-Werra'): 292.0,
#  ('D', 'river-Weser'): 440.0,
#  ('D', 'river-Wurm'): 35.0,
#  ('D A', 'river-Iller'): 147.0,
#  ('D A', 'river-Isar'): 295.0,
#  ('D A', 'river-Lech'): 264.0,
#  ('D CH FL A F NL', 'river-Rhein'): 1324.0,
#  ('D CZ', 'river-Elbe'): 1091.0,
#  ('D F', 'river-Saar'): 227.0,
#  ('D L F', 'river-Mosel'): 544.0,
#  ('D PL CZ', 'river-Oder'): 866.0,
#  ('E', 'river-Ebro'): 925.0,
#  ('E', 'river-Guadalquivir'): 657.0,
#  ('E P', 'river-Douro'): 897.0,
#  ('E P', 'river-Guadiana'): 742.0,
#  ('E P', 'river-Tajo'): 1007.0,
#  ('EAT RWA EAU', 'river-Akagera'): 275.0,
#  ('ETH SP', 'river-Jubba'): 1658.0,
#  ('ETH SP', 'river-Shabelle'): 1820.0,
#  ('F', 'river-Isere'): 290.0,
#  ('F', 'river-Loire'): 1013.0,
#  ('F', 'river-Marne'): 514.0,
#  ('F', 'river-Saone'): 480.0,
#  ('F', 'river-Seine'): 776.0,
#  ('F CH', 'river-Doubs'): 453.0,
#  ('F CH', 'river-Rhone'): 812.0,
#  ('F E', 'river-Garonne'): 647.0,
#  ('GB', 'river-Themse'): 346.0,
#  ('GH BF', 'river-Volta'): 1500.0,
#  ('H UA SRB', 'river-Theiss'): 1308.0,
#  ('I', 'river-Adda'): 313.0,
#  ('I', 'river-Arno'): 240.0,
#  ('I', 'river-Etsch'): 415.0,
#  ('I', 'river-Mincio'): 75.0,
#  ('I', 'river-Po'): 652.0,
#  ('I', 'river-Tiber'): 405.0,
#  ('I A SLO HR H', 'river-Drau'): 749.0,
#  ('IL WEST JOR SYR RL', 'river-Jordan'): 251.0,
#  ('IND BD', 'river-Ganges'): 2511.0,
#  ('IR', 'river-Karun'): 950.0,
#  ('IRQ IR', 'river-SchattAlArab'): 193.0,
#  ('IS', 'river-Joekulsa_a_Fjoellum'): 206.0,
#  ('IS', 'river-Thjorsa'): 230.0,
#  ('KAZ UZB TAD', 'river-Syrdarja'): 2129.0,
#  ('LS NAM RSA', 'river-Oranje'): 2160.0,
#  ('MEX', 'river-RioLerma'): 965.0,
#  ('MEX USA', 'river-Colorado_River'): 2330.0,
#  ('MEX USA', 'river-RioGrande'): 3034.0,
#  ('MNE', 'river-Moraca'): 99.5,
#  ('MNE BIH', 'river-Piva'): 120.0,
#  ('MNE BIH', 'river-Tara'): 140.0,
#  ('MW MOC', 'river-Shire'): 402.0,
#  ('MYA CN', 'river-Irawaddy'): 2170.0,
#  ('MYA CN', 'river-Saluen'): 2980.0,
#  ('N', 'river-Glomma'): 604.0,
#  ('N', 'river-Lagen'): 322.0,
#  ('N S', 'river-Klaraelv'): 460.0,
#  ('NIC CR', 'river-RioSanJuan'): 199.0,
#  ('NL B F', 'river-Maas'): 925.0,
#  ('PK IND CN', 'river-Indus'): 3180.0,
#  ('PL', 'river-Weichsel'): 1047.0,
#  ('PL BY', 'river-Narew'): 448.0,
#  ('PL BY UA', 'river-WesternBug'): 772.0,
#  ('R', 'river-Angara'): 1779.0,
#  ('R', 'river-Chatanga'): 1636.0,
#  ('R', 'river-Don'): 1870.0,
#  ('R', 'river-Jenissej'): 4092.0,
#  ('R', 'river-Kama'): 1805.0,
#  ('R', 'river-Katun'): 688.0,
#  ('R', 'river-Kolyma'): 2129.0,
#  ('R', 'river-Lena'): 4400.0,
#  ('R', 'river-Newa'): 74.0,
#  ('R', 'river-Noerdliche_Dwina'): 740.0,
#  ('R', 'river-Ob'): 3650.0,
#  ('R', 'river-Oka'): 1480.0,
#  ('R', 'river-Petschora'): 1809.0,
#  ('R', 'river-Schilka'): 560.0,
#  ('R', 'river-Suchona'): 558.0,
#  ('R', 'river-Swir'): 224.0,
#  ('R', 'river-Wolga'): 3531.0,
#  ('R CN', 'river-Amur'): 2824.0,
#  ('R CN', 'river-Argun'): 1620.0,
#  ('R EW', 'river-Narva'): 78.0,
#  ('R KAZ', 'river-Ischim'): 2450.0,
#  ('R KAZ', 'river-Tobol'): 1591.0,
#  ('R KAZ', 'river-Ural'): 2428.0,
#  ('R KAZ CN', 'river-Irtysch'): 4248.0,
#  ('R MNG', 'river-Selenge'): 992.0,
#  ('RA BR PY', 'river-Paraguay'): 2549.0,
#  ('RA BR PY', 'river-Parana'): 3998.0,
#  ('RCB ZRE', 'river-Zaire'): 4374.0,
#  ('RG WAG SN', 'river-Gambia'): 1120.0,
#  ('RI', 'river-Asahan'): 150.0,
#  ('RMM CI', 'river-Bani'): 430.0,
#  ('RMM RIM SN RG', 'river-Senegal'): 1430.0,
#  ('RMM RN WAN RG', 'river-Niger'): 4184.0,
#  ('RO', 'river-Olt'): 615.0,
#  ('RO MD UA', 'river-Pruth'): 953.0,
#  ('RSA', 'river-Vaal'): 1251.0,
#  ('RSA MOC ZW RB', 'river-Limpopo'): 1750.0,
#  ('S', 'river-Dalaelv'): 520.0,
#  ('S', 'river-Goetaaelv'): 93.0,
#  ('S', 'river-Oesterdalaelv'): 241.0,
#  ('S', 'river-Umeaelv'): 470.0,
#  ('S', 'river-Vaesterdalaelv'): 320.0,
#  ('SF', 'river-Kemijoki'): 550.0,
#  ('SF', 'river-Kokemaeenjoki'): 121.0,
#  ('SF', 'river-Kymijoki'): 203.0,
#  ('SF', 'river-Oulujoki'): 107.0,
#  ('SF', 'river-Ounasjoki'): 300.0,
#  ('SF N R', 'river-Paatsjoki'): 145.0,
#  ('SF R', 'river-Vuoksi'): 162.0,
#  ('SK', 'river-Waag'): 403.0,
#  ('SLO HR BIH SRB', 'river-Save'): 945.0,
#  ('SRB', 'river-Morava'): 185.0,
#  ('SRB', 'river-WesternMorava'): 308.0,
#  ('SRB A D H HR SK BG RO MD UA', 'river-Donau'): 2845.0,
#  ('SRB KOS MK', 'river-SouthernMorava'): 295.0,
#  ('SSD', 'river-Bahr_el-Gasal'): 716.0,
#  ('SSD', 'river-Sobat'): 740.0,
#  ('SSD ETH', 'river-Baro'): 306.0,
#  ('SSD ETH', 'river-Pibor'): 320.0,
#  ('SUD ETH', 'river-Atbara'): 1120.0,
#  ('SUD ETH', 'river-Blauer_Nil'): 1783.0,
#  ('TAD', 'river-Bartang'): 133.0,
#  ('TAD AFG', 'river-Murgab'): 395.0,
#  ('TAD AFG TM UZB', 'river-Amudarja'): 1415.0,
#  ('TCH CAM RCA', 'river-Schari'): 1400.0,
#  ('TR', 'river-Karasu'): 720.0,
#  ('TR', 'river-Murat'): 720.0,
#  ('TR GE AZ', 'river-Kura'): 1364.0,
#  ('TR SYR IRQ', 'river-Euphrat'): 2736.0,
#  ('TR SYR IRQ', 'river-Tigris'): 1900.0,
#  ('UA MD', 'Dnjestr'): 1352.0,
#  ('UA MD', 'river-Dnister'): 1352.0,
#  ('USA', 'river-Allegheny'): 523.0,
#  ('USA', 'river-Arkansas_River'): 2334.0,
#  ('USA', 'river-Connecticut_River'): 655.0,
#  ('USA', 'river-Hudson_River'): 493.0,
#  ('USA', 'river-MerrimackRiver'): 177.0,
#  ('USA', 'river-Mississippi_River'): 3778.0,
#  ('USA', 'river-Missouri_River'): 4130.0,
#  ('USA', 'river-Ohio'): 1579.0,
#  ('USA', 'river-Straits-of-Mackinac'): 0.1,
#  ('USA', 'river-TennesseeRiver'): 1049.0,
#  ('USA', 'river-TruckeeRiver'): 225.0,
#  ('UZB KGZ', 'river-Naryn'): 807.0,
#  ('WAN CAM', 'river-Benue'): 1400.0,
#  ('YV CO', 'river-Orinoco'): 2140.0,
#  ('ZRE', 'river-Aruwimi'): 1287.0,
#  ('ZRE', 'river-Busira'): 830.0,
#  ('ZRE', 'river-Fimi'): 200.0,
#  ('ZRE', 'river-Kwa'): 100.0,
#  ('ZRE', 'river-Lomami'): 1450.0,
#  ('ZRE', 'river-Lukenie'): 900.0,
#  ('ZRE', 'river-Lukuga'): 350.0,
#  ('ZRE', 'river-Lulua'): 970.0,
#  ('ZRE', 'river-Luvua'): 350.0,
#  ('ZRE', 'river-Ruki'): 130.0,
#  ('ZRE', 'river-Tshuapa'): 1300.0,
#  ('ZRE', 'river-Uelle'): 1130.0,
#  ('ZRE EAU', 'river-Semliki'): 230.0,
#  ('ZRE RCA', 'river-Bomu'): 280.0,
#  ('ZRE RCA RCB', 'river-Ubangi'): 1120.0,
#  ('ZRE RWA BI', 'river-Ruzizi'): 104.0,
#  ('ZRE Z', 'river-Luapula'): 300.0}

# %%
dict_lake = {}

for lakes in root:
    if (lakes.tag == 'lake'):
        country_id=lakes.attrib['country']
        lake_id =lakes.attrib['id']
        for stuff in lakes:
            if (stuff.tag=='area'):
                dict_lake[(country_id, lake_id)]=float(stuff.text)

# %%
dict_lake
# Out:
# {('A D CH', 'lake-Bodensee'): 538.5,
#  ('A H', 'lake-Neusiedlersee'): 320.0,
#  ('AL MK', 'lake-Ohridsee'): 367.0,
#  ('AL MK GR', 'lake-Prespasee'): 273.0,
#  ('AL MNE', 'lake-Skutarisee'): 368.0,
#  ('AUS', 'lake-Eyre_See'): 9500.0,
#  ('AUS', 'lake-LakeBurleyGriffin'): 6.64,
#  ('AUS', 'lake-LakeEucumbene'): 145.0,
#  ('AUS', 'lake-LakeHume'): 202.0,
#  ('AUS', 'lake-LakeJindabyne'): 30.0,
#  ('BOL', 'lake-Poopo'): 1340.0,
#  ('BOL', 'lake-SalarDeUyuni'): 10582.0,
#  ('BOL PE', 'lake-Titicaca_See'): 8372.0,
#  ('BR', 'lake-LagoSobradinho'): 4214.0,
#  ('CDN', 'lake-AtlinLake'): 798.0,
#  ('CDN', 'lake-Great_Bear_Lake'): 31792.0,
#  ('CDN', 'lake-Great_Slave_Lake'): 28568.0,
#  ('CDN', 'lake-Lake_Manitou'): 104.0,
#  ('CDN', 'lake-Lake_Nipigon'): 4848.0,
#  ('CDN', 'lake-Lake_Winnipeg'): 24420.0,
#  ('CDN', 'lake-Manicouagan'): 1942.0,
#  ('CDN USA', 'lake-Lake_Erie'): 25745.0,
#  ('CDN USA', 'lake-Lake_Huron'): 59600.0,
#  ('CDN USA', 'lake-Lake_Ontario'): 18960.0,
#  ('CDN USA', 'lake-Lake_Superior'): 82103.0,
#  ('CH', 'lake-Brienzersee'): 29.8,
#  ('CH', 'lake-Thunersee'): 48.3,
#  ('CH', 'lake-Vierwaldstattersee'): 113.7,
#  ('CH', 'lake-Zurichsee'): 88.0,
#  ('CN', 'lake-LopNor'): 5000.0,
#  ('CN', 'lake-NamCo'): 1855.0,
#  ('CN', 'lake-Qinghai'): 4583.0,
#  ('CR', 'lake-IrazuLake'): 1.0,
#  ('D', 'lake-Ammersee'): 46.6,
#  ('D', 'lake-Chiemsee'): 80.0,
#  ('D', 'lake-LaacherMaar'): 3.3,
#  ('D', 'lake-StarnbergerSee'): 56.36,
#  ('DJI', 'lake-Assalesee'): 54.0,
#  ('DJI ETH', 'lake-LakeAbbe'): 320.0,
#  ('DK', 'lake-Arresoe'): 40.2,
#  ('E', 'lake-LagunaDeGallocanta'): 14.4,
#  ('EAT', 'lake-Ejassisee'): 1050.0,
#  ('EAT', 'lake-Natronsee'): 1040.0,
#  ('EAT', 'lake-Rukwasee'): 5760.0,
#  ('EAT EAK EAU', 'lake-Victoriasee'): 68870.0,
#  ('EAU', 'lake-Kiogasee'): 1720.0,
#  ('EAU ZRE', 'lake-Albertsee'): 5347.0,
#  ('ET SUD', 'lake-Nassersee'): 5250.0,
#  ('ETH', 'lake-Abayasee'): 1285.0,
#  ('ETH', 'lake-Tanasee'): 3000.0,
#  ('ETH EAK', 'lake-Rudolfsee'): 6405.0,
#  ('ETH EAK', 'lake-Stefaniesee'): 800.0,
#  ('F CH', 'lake-Genfer_See'): 581.0,
#  ('GB', 'lake-LochLomond'): 71.0,
#  ('GB', 'lake-LochNess'): 56.0,
#  ('GH', 'lake-Bosumtwi'): 49.0,
#  ('GH', 'lake-Voltastausee'): 8502.0,
#  ('H', 'lake-Balaton'): 594.0,
#  ('I', 'lake-Bolsena'): 114.0,
#  ('I', 'lake-Bracciano'): 57.0,
#  ('I', 'lake-Comer_See'): 146.0,
#  ('I', 'lake-Gardasee'): 370.0,
#  ('I', 'lake-Trasimeno'): 128.0,
#  ('I CH', 'lake-Lago_Maggiore'): 216.0,
#  ('IL JOR WEST', 'lake-DeadSea'): 41650.0,
#  ('IL SYR', 'lake-SeeGenezareth'): 165.0,
#  ('IR', 'lake-Hamune_Jazmurian_See'): 1600.0,
#  ('IR', 'lake-Namak_See'): 1800.0,
#  ('IR', 'lake-Urmia'): 5470.0,
#  ('KAZ', 'lake-Balchaschsee'): 18428.0,
#  ('KGZ', 'lake-Issyk-Kul'): 6236.0,
#  ('MEX', 'lake-Lago_de_Chapala'): 1685.0,
#  ('MOC', 'lake-Cabora-Bassa-See'): 2800.0,
#  ('MW MOC', 'lake-Chilwasee'): 687.0,
#  ('MW MOC EAT', 'lake-Malawi'): 29600.0,
#  ('N', 'lake-MjoesaSee'): 368.0,
#  ('NAM', 'lake-Etoschapfanne'): 6133.0,
#  ('NIC', 'lake-Managua'): 1035.0,
#  ('NIC CR', 'lake-Nicaragua_See'): 8157.0,
#  ('R', 'lake-Baikalsee'): 31492.0,
#  ('R', 'lake-KuybyshevReservoir'): 6450.0,
#  ('R', 'lake-Ladogasee'): 18400.0,
#  ('R', 'lake-Onegasee'): 9.616,
#  ('R', 'lake-Taimyrsee'): 4560.0,
#  ('R', 'lake-Tschanysee'): 2500.0,
#  ('R AZ KAZ IR TM', 'lake-KaspischesMeer'): 386400.0,
#  ('R CN', 'lake-Chankasee'): 4400.0,
#  ('R EW', 'lake-Pskowsee'): 3555.0,
#  ('RA', 'lake-LagunaMarChiquita'): 5770.0,
#  ('RB', 'lake-Makarikarisalzpfanne'): 12000.0,
#  ('RB', 'lake-Ngamisee'): 770.0,
#  ('RCB ZRE', 'lake-Malebo-Pool'): 500.0,
#  ('RCH BOL', 'lake-LicancaburCrater'): 0.005,
#  ('RI', 'lake-SegaraAnak'): 11.3,
#  ('RI', 'lake-Toba'): 1103.0,
#  ('RN WAN TCH CAM', 'lake-Tschadsee'): 23000.0,
#  ('RP', 'lake-LagunaDeBay'): 911.0,
#  ('S', 'lake-Maelarsee'): 1140.0,
#  ('S', 'lake-Siljan'): 290.0,
#  ('S', 'lake-Storuman'): 173.0,
#  ('S', 'lake-Vaenersee'): 5648.0,
#  ('S', 'lake-Vaettersee'): 1900.0,
#  ('SF', 'lake-Inarisee'): 1040.0,
#  ('SF', 'lake-Kallavesi'): 472.0,
#  ('SF', 'lake-Oulujaervi'): 928.0,
#  ('SF', 'lake-Paeijaenne'): 1118.0,
#  ('SF', 'lake-Saimaa'): 4370.0,
#  ('TAD', 'lake-Sarez'): 80.0,
#  ('TR', 'lake-Keban'): 675.0,
#  ('TR', 'lake-Vansee'): 3740.0,
#  ('UA', 'lake-KakhovkaReservoir'): 2155.0,
#  ('UA', 'lake-KievReservoir'): 922.0,
#  ('UA', 'lake-KremenchukReservoir'): 2252.0,
#  ('USA', 'lake-Chickamauga_Lake'): 147.0,
#  ('USA', 'lake-CraterLake'): 53.2,
#  ('USA', 'lake-F-D-R-_Lake'): 337.0,
#  ('USA', 'lake-FortPeckLake'): 981.0,
#  ('USA', 'lake-Great_Salt_Lake'): 4400.0,
#  ('USA', 'lake-Kentucky_Lake'): 648.0,
#  ('USA', 'lake-LakeOahe'): 1453.0,
#  ('USA', 'lake-Lake_Mead'): 640.0,
#  ('USA', 'lake-Lake_Michigan'): 57800.0,
#  ('USA', 'lake-Lake_Okeechobee'): 1890.0,
#  ('USA', 'lake-Lake_Powell'): 645.0,
#  ('USA', 'lake-Lake_Tahoe'): 497.0,
#  ('USA', 'lake-Lake_Winnipesaukee'): 186.0,
#  ('USA', 'lake-PyramidLake'): 487.0,
#  ('USA', 'lake-Sakakawea'): 1578.0,
#  ('USA CDN', 'lake-Champlain'): 1130.0,
#  ('UZB KAZ', 'lake-Aralsee'): 17160.0,
#  ('WAN', 'lake-Kainji-Stausee'): 1243.0,
#  ('YV', 'lake-Maracaibo_See'): 13000.0,
#  ('Z', 'lake-Bangweolosee'): 10000.0,
#  ('Z ZW', 'lake-Karibasee'): 5580.0,
#  ('ZRE', 'lake-MaiNdombe'): 8200.0,
#  ('ZRE EAU', 'lake-Rutanzige'): 2325.0,
#  ('ZRE RWA', 'lake-Kiwusee'): 2650.0,
#  ('ZRE Z', 'lake-Mwerusee'): 5120.0,
#  ('ZRE Z BI EAT', 'lake-Tanganjikasee'): 32893.0}

# %%
dict_airport = {}

for airports in root:
    if (airports.tag == 'airport'):
        country_id = airports.attrib['country']     
        for stuff in airports:
            if (stuff.tag=='name'):
                airport_id=stuff.text
            elif (stuff.tag == 'elevation'):
                if (stuff.text):
                    dict_airport[(country_id, airport_id)]=float(stuff.text)

# %%
dict_airport
# Out:
# {('MNTS', 'John A. Osborne'): 168.0,
#  ('CN', 'Baita Airport'): 1084.0,
#  ('CN', 'Yibin'): 305.0,
#  ('R', 'Elista Airport'): 153.0,
#  ('F', 'Basel Mulhouse'): 270.0,
#  ('BOL', 'Viru Viru Intl'): 373.0,
#  ('CN', 'Lanzhou Airport'): 1948.0,
#  ('CH', 'Bern Belp'): 510.0,
#  ('USA', 'Honolulu Intl'): 4.0,
#  ('CN', 'Tongliao Airport'): 730.0,
#  ('MW', 'Kamuzu Intl'): 1230.0,
#  ('IR', 'Ahwaz'): 20.0,
#  ('DK', 'Aarhus'): 25.0,
#  ('USA', 'Spokane Intl'): 724.0,
#  ('IND', 'Devi Ahilyabai Holkar'): 564.0,
#  ('E', 'Valencia'): 69.0,
#  ('MAL', 'Labuan'): 31.0,
#  ('USA', 'Orlando Intl'): 29.0,
#  ('BR', 'Governador Valadares Airport'): 171.0,
#  ('BZ', 'Philip S W Goldson Intl'): 5.0,
#  ('PNG', 'Port Moresby Jacksons Intl'): 45.0,
#  ('USA', 'Boise Air Terminal'): 875.0,
#  ('N', 'Framnes'): 30.0,
#  ('GR', 'Ioannis Kapodistrias Intl'): 2.0,
#  ('CN', 'Yushu Batang'): 3963.0,
#  ('YV', 'Simon Bolivar Intl'): 72.0,
#  ('ARM', 'Zvartnots'): 865.0,
#  ('CN', 'Qingshan'): 1559.0,
#  ('IND', 'Port Blair'): 4.0,
#  ('I', 'Pescara'): 15.0,
#  ('KAZ', 'Kzylorda'): 131.0,
#  ('MEX', 'General Francisco J Mujica Intl'): 1839.0,
#  ('PL', 'Strachowice'): 123.0,
#  ('S', 'Kalmar'): 5.0,
#  ('F', 'Val De Loire'): 109.0,
#  ('BR', 'Pelotas'): 18.0,
#  ('DZ', 'Es Senia'): 90.0,
#  ('MACX', 'Macao Intl'): 6.0,
#  ('D', 'Hannover'): 56.0,
#  ('USA', 'Erie Intl Tom Ridge Fld'): 223.0,
#  ('BR', 'Pinto Martins Intl'): 25.0,
#  ('P', 'Sao Jorge'): 95.0,
#  ('I', 'Malpensa'): 234.0,
#  ('RI', 'Radin Inten II (Branti) Airport'): 86.0,
#  ('D', u'M\xfcnster Osnabr\xfcck'): 49.0,
#  ('PE', 'Capt Jose A Quinones Gonzales Intl'): 30.0,
#  ('CDN', 'Thunder Bay'): 199.0,
#  ('CO', 'Olaya Herrera'): 1506.0,
#  ('ANG', 'Huambo'): 1703.0,
#  ('CN', 'Wuxi Airport'): 5.0,
#  ('RCH', 'Chacalluta'): 51.0,
#  ('I', 'Genova Sestri'): 4.0,
#  ('ET', 'Aswan Intl'): 202.0,
#  ('UA', 'Boryspil Intl'): 130.0,
#  ('CN', 'Lhasa-Gonggar'): 4005.0,
#  ('REUN', 'St Denis Gillot'): 20.0,
#  ('GR', 'Kefallinia'): 18.0,
#  ('SN', 'Ziguinchor'): 23.0,
#  ('R', 'Domododevo'): 179.0,
#  ('MAL', 'Sultan Azlan Shah'): 40.0,
#  ('ET', 'Hurghada Intl'): 16.0,
#  ('IL', 'Ben Gurion'): 41.0,
#  ('ANG', 'Menongue'): 1363.0,
#  ('SA', 'Taif'): 1478.0,
#  ('CAYM', 'Gerrard Smith Intl'): 2.0,
#  ('NMIS', 'Francisco C Ada Saipan Intl'): 66.0,
#  ('MEX', 'Valle Del Fuerte Intl'): 5.0,
#  ('USA', 'Helena Rgnl'): 1182.0,
#  ('GQ', 'Bata'): 11.0,
#  ('DZ', 'Mohamed Boudiaf Intl'): 691.0,
#  ('TAD', 'Dushanbe'): 785.0,
#  ('WAN', 'Ilorin'): 343.0,
#  ('RA', 'Posadas'): 131.0,
#  ('GB', 'Bristol'): 190.0,
#  ('I', 'Perugia'): 211.0,
#  ('A', 'Linz'): 298.0,
#  ('IND', 'Bhubaneshwar'): 42.0,
#  ('TR', 'Hatay Airport'): 8.0,
#  ('E', 'Menorca'): 91.0,
#  ('GR', 'Ioannina'): 475.0,
#  ('MAL', 'Sultan Ismail'): 41.0,
#  ('MA', 'Inezgane'): 27.0,
#  ('CN', 'Liuting'): 10.0,
#  ('F', 'Mediterranee'): 5.0,
#  ('MAL', 'Kuantan'): 18.0,
#  ('SLO', 'Ljubljana'): 388.0,
#  ('CO', 'Simon Bolivar'): 7.0,
#  ('RCH', 'Carriel Sur Intl'): 8.0,
#  ('GB', 'Edinburgh'): 41.0,
#  ('R', 'Abakan'): 253.0,
#  ('EC', 'Seymour'): 63.0,
#  ('NL', 'Schiphol'): -3.0,
#  ('CN', 'Changchun'): 69.0,
#  ('NIUE', 'Niue Intl'): 64.0,
#  ('IND', 'Jabalpur'): 495.0,
#  ('PL', 'Bydgoszcz Ignacy Jan Paderewski Airport'): 72.0,
#  ('E', 'Talavera La Real'): 186.0,
#  ('PE', 'Pedro Canga'): 35.0,
#  ('RI', 'Adi Sutjipto'): 107.0,
#  ('IND', 'Birsa Munda'): 655.0,
#  ('G', 'Leon M Ba'): 12.0,
#  ('SY', 'Seychelles Intl'): 3.0,
#  ('CN', 'Xuzhou Guanyin Airport'): 43.0,
#  ('N', 'Gardermoen'): 208.0,
#  ('CR', 'Tobias Bolanos International Airport'): 1002.0,
#  ('GB', 'City'): 5.0,
#  ('RI', 'Hasanuddin'): 14.0,
#  ('RI', 'Hang Nadim'): 38.0,
#  ('J', 'Naha'): 4.0,
#  ('MAL', 'Sultan Abdul Aziz Shah Intl'): 27.0,
#  ('GB', 'Leeds Bradford'): 208.0,
#  ('EAT', 'Zanzibar'): 16.0,
#  ('CN', 'Baoan Intl'): 4.0,
#  ('MAL', 'Sultan Mahmud'): 6.0,
#  ('SA', 'King Fahd Intl'): 22.0,
#  ('BF', 'Ouagadougou'): 316.0,
#  ('CO', 'Matecana'): 1346.0,
#  ('BR', 'Tancredo Neves Intl'): 828.0,
#  ('MEX', 'General Servando Canales Intl'): 8.0,
#  ('VN', 'Rach Gia'): 2.0,
#  ('J', 'Sendai'): 5.0,
#  ('J', 'Toyama'): 29.0,
#  ('RI', 'Sultan Syarif Kasim Ii'): 31.0,
#  ('MW', 'Chileka Intl'): 779.0,
#  ('TR', 'Adana'): 20.0,
#  ('USA', 'Mobile Rgnl'): 67.0,
#  ('I', 'Pisa'): 2.0,
#  ('ET', 'Alexandria Intl'): -2.0,
#  ('RCH', 'Diego Aracena Intl'): 47.0,
#  ('USA', 'Lehigh Valley Intl'): 120.0,
#  ('RI', 'Depati Amir'): 33.0,
#  ('THA', 'Suvarnabhumi Intl'): 2.0,
#  ('IND', 'Aizawl'): 305.0,
#  ('MA', 'Sale'): 84.0,
#  ('CN', 'Shuangliu'): 495.0,
#  ('K', 'Phnom Penh Intl'): 12.0,
#  ('USA', 'Corpus Christi Intl'): 13.0,
#  ('SF', 'Joensuu'): 121.0,
#  ('I', 'Torino'): 302.0,
#  ('RI', 'Sultan Thaha'): 25.0,
#  ('USA', 'Denver Intl'): 1656.0,
#  ('USA', 'Charlotte Douglas Intl'): 228.0,
#  ('M', 'Luqa'): 91.0,
#  ('F', 'St Jacques'): 38.0,
#  ('KAZ', 'Aktyubinsk'): 225.0,
#  ('TL', 'Presidente Nicolau Lobato Intl'): 8.0,
#  ('SA', 'King Abdulaziz Intl'): 15.0,
#  ('GR', 'Nikos Kazantzakis'): 35.0,
#  ('D', 'Neuenland'): 4.0,
#  ('RCH', 'Maquehue'): 93.0,
#  ('J', 'Tokyo Intl'): 11.0,
#  ('GB', 'Stansted'): 106.0,
#  ('D', 'Leipzig Halle'): 142.0,
#  ('UZB', 'Bukhara'): 229.0,
#  ('I', 'Capodichino'): 90.0,
#  ('USA', 'Tulsa Intl'): 206.0,
#  ('UA', 'Ivano Frankivsk International Airport'): 280.0,
#  ('OM', 'Seeb Intl'): 15.0,
#  ('PE', 'Rodriguez Ballon'): 2563.0,
#  ('USA', 'Akron Canton Regional Airport'): 374.0,
#  ('BR', 'Guarulhos Gov Andre Franco Montouro'): 750.0,
#  ('J', 'Kumamoto'): 196.0,
#  ('SVAX', 'Longyear'): 27.0,
#  ('CN', 'Wuxu'): 128.0,
#  ('CN', 'Shenyang Taoxian International Airport'): 60.0,
#  ('GROX', 'Nuuk'): 86.0,
#  ('SF', 'Oulu'): 14.0,
#  ('TO', 'Fua Amotu Intl'): 38.0,
#  ('NLSM', 'Princess Juliana Intl'): 4.0,
#  ('USA', 'Memphis Intl'): 104.0,
#  ('MEX', 'Plan De Guadalupe Intl'): 1457.0,
#  ('F', 'Angers-Loire Airport'): 59.0,
#  ('EC', 'Jose Joaquin De Olmedo Intl'): 6.0,
#  ('MAL', 'Sultan Ismail Petra'): 5.0,
#  ('IND', 'Dr Ambedkar Intl'): 315.0,
#  ('RCH', 'La Florida'): 147.0,
#  ('GR', 'Samos'): 6.0,
#  ('Z', 'Lusaka Intl'): 1152.0,
#  ('RSA', 'Port Elizabeth Intl'): 69.0,
#  ('BR', 'Boa Vista'): 84.0,
#  ('EAK', 'Nairobi Wilson'): 1691.0,
#  ('MEX', 'Lencero Airport'): 953.0,
#  ('CN', 'Tianhe'): 34.0,
#  ('RT', 'Gnassingbe Eyadema Intl'): 22.0,
#  ('BHT', 'Paro'): 2235.0,
#  ('SYR', 'Aleppo Intl'): 383.0,
#  ('IND', 'Bhopal'): 524.0,
#  ('THA', 'Phuket Intl'): 25.0,
#  ('MA', 'Ibn Batouta'): 19.0,
#  ('USA', 'Buffalo Niagara Intl'): 221.0,
#  ('USA', 'Albert J Ellis'): 29.0,
#  ('MEX', 'Colima'): 752.0,
#  ('YV', 'Maturin'): 68.0,
#  ('DOM', 'Cibao Intl'): 172.0,
#  ('RA', 'Mar Del Plata'): 22.0,
#  ('TR', 'Agri Airport'): 1665.0,
#  ('N', 'Airport'): 39.0,
#  ('NL', 'Maastricht'): 114.0,
#  ('IND', 'Chandigarh'): 309.0,
#  ('IND', 'Cochin'): 2.0,
#  ('RIM', 'Nouadhibou'): 5.0,
#  ('IS', 'Keflavik International Airport'): 52.0,
#  ('E', 'Sevilla'): 34.0,
#  ('MEX', 'Licenciado Y Gen Ignacio Lopez Rayon'): 1603.0,
#  ('D', 'Dortmund'): 130.0,
#  ('ETH', 'Dire Dawa Intl'): 1167.0,
#  ('DOM', 'Las Americas Intl'): 18.0,
#  ('D', 'Stuttgart'): 389.0,
#  ('RCB', 'Maya Maya'): 320.0,
#  ('RA', 'Resistencia'): 53.0,
#  ('GB', 'Robin Hood Doncaster Sheffield Airport'): 17.0,
#  ('CAM', 'Yaounde Nsimalen'): 695.0,
#  ('Z', 'Ndola'): 1270.0,
#  ('HCA', 'Toncontin Intl'): 1004.0,
#  ('TR', 'Adiyaman Airport'): 676.0,
#  ('YE', 'Aden Intl'): 2.0,
#  ('USA', 'Sacramento Intl'): 8.0,
#  ('RP', 'Bacolod'): 8.0,
#  ('B', 'Brussels South'): 187.0,
#  ('CO', 'Gustavo Rojas Pinilla'): 6.0,
#  ('CN', 'Dandong'): 9.0,
#  ('ZRE', 'Lubumbashi Intl'): 1309.0,
#  ('AUS', 'Brisbane Intl'): 4.0,
#  ('BD', 'Shah Amanat Intl'): 4.0,
#  ('LAR', 'Tripoli Intl'): 80.0,
#  ('RI', 'Soekarno Hatta Intl'): 10.0,
#  ('N', 'Kjevik'): 17.0,
#  ('CDN', 'Regina Intl'): 577.0,
#  ('RO', 'Oradea'): 142.0,
#  ('S', 'Skavsta'): 43.0,
#  ('PE', 'Coronel Fap Alfredo Mendivil Duarte'): 2719.0,
#  ('SF', 'Kuopio'): 98.0,
#  ('S', 'Save'): 18.0,
#  ('NEP', 'Tribhuvan Intl'): 1338.0,
#  ('USA', 'Modesto City Co Harry Sham'): 30.0,
#  ('WV', 'E T Joshua'): 20.0,
#  ('VN', 'Vinh Airport'): 7.0,
#  ('P', 'Faro'): 7.0,
#  ('USA', 'Adams Fld'): 80.0,
#  ('S', 'Karlstad Airport'): 107.0,
#  ('IND', 'Visakhapatnam'): 5.0,
#  ('MAL', 'Kuala Lumpur Intl'): 21.0,
#  ('BRU', 'Brunei Intl'): 22.0,
#  ('USA', 'William P Hobby'): 14.0,
#  ('J', 'Oita'): 6.0,
#  ('TR', 'Oguzeli'): 706.0,
#  ('PK', 'Sukkur'): 60.0,
#  ('J', 'New Kitakyushu'): 6.0,
#  ('R', 'Kadala'): 693.0,
#  ('GE', 'Batumi'): 32.0,
#  ('RA', 'Rio Gallegos'): 19.0,
#  ('YV', 'Barinas'): 203.0,
#  ('RI', 'Abdul Rachman Saleh'): 526.0,
#  ('MYA', 'Mandalay Intl'): 91.0,
#  ('KAZ', 'Shymkent'): 422.0,
#  ('USA', 'Chicago Midway Intl'): 189.0,
#  ('LB', 'Monrovia Roberts Intl'): 9.0,
#  ('I', 'Bari'): 54.0,
#  ('IND', 'Indira Gandhi Intl'): 237.0,
#  ('R', 'Gumrak'): 147.0,
#  ('CDN', 'Pierre Elliott Trudeau Intl'): 36.0,
#  ('CDN', 'Winnipeg Intl'): 239.0,
#  ('CDN', 'Vancouver Intl'): 4.0,
#  ('CL', 'Bandaranaike Intl Colombo'): 9.0,
#  ('USA', 'Tallahassee Rgnl'): 25.0,
#  ('RO', 'Sibiu'): 456.0,
#  ('CN', 'Baiyun Intl'): 15.0,
#  ('CN', 'Zhuhai Airport'): 7.0,
#  ('GB', 'Blackpool'): 10.0,
#  ('GBG', 'Guernsey'): 102.0,
#  ('YE', 'Sanaa Intl'): 2200.0,
#  ('Z', 'Livingstone'): 1007.0,
#  ('BR', 'Santos Dumont'): 3.0,
#  ('J', 'Tokushima'): 8.0,
#  ('DZ', 'Tamanrasset'): 1377.0,
#  ('ROK', 'Gimpo'): 18.0,
#  ('TR', 'Samsun-Carsamba Airport'): 5.0,
#  ('I', 'Reggio Calabria'): 29.0,
#  ('MS', 'Sir Seewoosagur Ramgoolam Intl'): 57.0,
#  ('RH', 'Toussaint Louverture Intl'): 37.0,
#  ('TR', 'Ataturk'): 50.0,
#  ('GB', 'Gatwick'): 62.0,
#  ('R', 'Tomsk Bogashevo Airport'): 182.0,
#  ('D', 'Hamburg'): 16.0,
#  ('YV', 'Casique Aramare'): 75.0,
#  ('CI', 'Abidjan Felix Houphouet Boigny Intl'): 6.0,
#  ('BR', 'Santa Genoveva'): 747.0,
#  ('USA', 'Rochester'): 402.0,
#  ('USA', 'Mc Ghee Tyson'): 299.0,
#  ('SA', 'Hail'): 1016.0,
#  ('USA', 'Philadelphia Intl'): 11.0,
#  ('F', 'Rivesaltes'): 44.0,
#  ('IND', 'Varanasi'): 81.0,
#  ('VN', 'Nha Trang'): 6.0,
#  ('R', 'Chertovitskoye'): 157.0,
#  ('RP', 'General Santos International Airport'): 9.0,
#  ('TR', 'Van'): 1671.0,
#  ('PK', 'Allama Iqbal Intl'): 217.0,
#  ('PE', 'Padre Aldamiz'): 201.0,
#  ('YV', 'Barquisimeto Intl'): 623.0,
#  ('YV', 'General Jose Antonio Anzoategui Intl'): 8.0,
#  ('TUCA', 'Providenciales'): 5.0,
#  ('PK', 'Faisalabad Intl'): 180.0,
#  ('MEX', 'Xoxocotlan Intl'): 1521.0,
#  ('CN', 'Baotou Airport'): 1013.0,
#  ('J', 'Aomori'): 202.0,
#  ('E', 'Pamplona'): 459.0,
#  ('GB', 'Gloucestershire'): 31.0,
#  ('CAM', 'Douala'): 10.0,
#  ('EAU', 'Entebbe Intl'): 1153.0,
#  ('CN', 'Jingdezhen Airport'): 34.0,
#  ('S', 'Sturup'): 72.0,
#  ('CN', 'Changle'): 14.0,
#  ('J', 'New Chitose'): 25.0,
#  ('USA', 'Austin Bergstrom Intl'): 165.0,
#  ('MOC', 'Nampula'): 440.0,
#  ('CY', 'Larnaca'): 2.0,
#  ('RA', 'Formosa'): 59.0,
#  ('EAK', 'Kisumu'): 1157.0,
#  ('PL', 'Goleniow'): 47.0,
#  ('CN', 'Shijiazhuang Daguocun International Airport'): 71.0,
#  ('USA', 'Hartsfield Jackson Atlanta Intl'): 313.0,
#  ('THA', 'Don Muang Intl'): 3.0,
#  ('IND', 'Dehradun'): 558.0,
#  ('CN', 'Diwopu'): 648.0,
#  ('R', 'Magnitogorsk'): 436.0,
#  ('IND', 'Allahabad'): 98.0,
#  ('BR', 'Macapa'): 17.0,
#  ('R', 'Shpakovskoye'): 453.0,
#  ('CN', 'Binhai'): 3.0,
#  ('AUS', 'Sydney Intl'): 6.0,
#  ('CO', 'Perales'): 914.0,
#  ('GB', 'Dyce'): 66.0,
#  ('GB', 'Cardiff'): 67.0,
#  ('KAZ', 'Aktau'): 6.0,
#  ('S', 'Jonkoping'): 226.0,
#  ('GB', 'Humberside'): 37.0,
#  ('GR', 'Rhodes Diagoras'): 5.0,
#  ('IND', 'Goa'): 56.0,
#  ('CN', 'Meilan'): 23.0,
#  ('GR', 'Makedonia'): 7.0,
#  ('VN', 'Tansonnhat Intl'): 10.0,
#  ('GB', 'Durham Tees Valley Airport'): 37.0,
#  ('GR', 'Syros Airport'): 72.0,
#  ('CN', 'Zhoushan Airport'): 9.0,
#  ('A', 'Schwechat'): 183.0,
#  ('BR', 'Deputado Luis Eduardo Magalhaes'): 20.0,
#  ('CDN', 'Quebec Jean Lesage Intl'): 74.0,
#  ('IRQ', 'Erbil Intl'): 409.0,
#  ('USA', 'Miami Intl'): 2.0,
#  ('RN', 'Diori Hamani'): 223.0,
#  ('RI', 'Sentani'): 88.0,
#  ('UA', 'Uzhhorod International Airport'): 117.0,
#  ('R', 'Bolshoye Savino'): 123.0,
#  ('CN', 'Datong Airport'): 1049.0,
#  ('GB', 'Glasgow'): 8.0,
#  ('UAE', 'Abu Dhabi Intl'): 27.0,
#  ('KAZ', 'Astana Intl'): 355.0,
#  ('R', 'Uytash'): 4.0,
#  ('WAN', 'Kaduna'): 632.0,
#  ('AUS', 'Canberra'): 575.0,
#  ('KN', 'Robert L Bradshaw'): 52.0,
#  ('MAYO', 'Dzaoudzi Pamandzi'): 7.0,
#  ('R', 'Kemerovo'): 263.0,
#  ('WAN', 'Murtala Muhammed'): 41.0,
#  ('TAD', 'Kulob Airport'): 699.0,
#  ('UA', 'Dnipropetrovsk Intl'): 147.0,
#  ('BR', 'Prefeito Renato Moreira'): 131.0,
#  ('GBJ', 'Jersey'): 84.0,
#  ('P', 'Pico'): 33.0,
#  ('J', 'Miyazaki'): 6.0,
#  ('R', 'Kazan'): 125.0,
#  ('WAN', 'Yakubu Gowon'): 1290.0,
#  ('USA', 'Evansville Regional'): 127.0,
#  ('RCH', 'Pichoy'): 18.0,
#  ('USA', 'Salt Lake City Intl'): 1289.0,
#  ('P', 'Porto'): 70.0,
#  ('LT', 'Kaunas Intl'): 78.0,
#  ('USA', 'John Wayne Arpt Orange Co'): 17.0,
#  ('CDN', 'Calgary Intl'): 1084.0,
#  ('USA', 'George Bush Intcntl Houston'): 30.0,
#  ('F', 'Entzheim'): 154.0,
#  ('USA', 'Fort Lauderdale Hollywood Intl'): 3.0,
#  ('USA', 'La Guardia'): 7.0,
#  ('COCO', 'Cocos Keeling Island Airport'): 3.0,
#  ('E', 'Gran Canaria'): 24.0,
#  ('AUS', 'Melbourne Intl'): 132.0,
#  ('BR', 'Viracopos'): 662.0,
#  ('KWT', 'Kuwait Intl'): 63.0,
#  ('DZ', 'Cheikh Larbi Tebessi'): 811.0,
#  ('GR', 'Mitilini'): 18.0,
#  ('AUS', 'Hobart'): 4.0,
#  ('KAZ', 'Pavlodar'): 125.0,
#  ('ARU', 'Reina Beatrix Intl'): 18.0,
#  ('MEX', 'Hermanos Serdan Intl'): 2244.0,
#  ('GB', 'Manchester'): 78.0,
#  ('BR', 'Ten Cel Av Cesar Bombonato'): 943.0,
#  ('IND', 'Surat'): 5.0,
#  ('SD', 'Matsapha'): 633.0,
#  ('R', 'Omsk'): 95.0,
#  ('USA', 'Portland Intl Jetport'): 23.0,
#  ('E', 'Santiago'): 370.0,
#  ('CN', 'Korla Airport'): 927.0,
#  ('USA', 'Louis Armstrong New Orleans Intl'): 1.0,
#  ('PK', 'Multan Intl'): 123.0,
#  ('CN', 'Wanzhou Wuqiao Airport'): 567.0,
#  ('RL', 'Rafic Hariri Intl'): 27.0,
#  ('LT', 'Vilnius Intl'): 197.0,
#  ('F', 'Saint Exupery'): 250.0,
#  ('WL', 'George F L Charles'): 7.0,
#  ('PK', 'Quetta'): 1606.0,
#  ('USA', 'Eppley Afld'): 300.0,
#  ('IND', 'Calicut'): 104.0,
#  ('PE', 'Capitan Fap Guillermo Concha Iberico'): 37.0,
#  ('CN', 'Pudong'): 4.0,
#  ('CN', 'Wusu'): 785.0,
#  ('RB', 'Sir Seretse Khama Intl'): 1006.0,
#  ('D', 'Frankfurt Main'): 111.0,
#  ('WAN', 'Yola'): 183.0,
#  ('TR', 'Batman'): 555.0,
#  ('C', 'Jose Marti Intl'): 64.0,
#  ('GR', 'Mikonos'): 123.0,
#  ('PE', 'Coronel Francisco Secada Vignetta Intl'): 93.0,
#  ('R', 'Sochi'): 27.0,
#  ('USA', 'Louisville International Airport'): 153.0,
#  ('MEX', 'Angel Albino Corzo'): 455.0,
#  ('RCH', 'Cerro Moreno Intl'): 139.0,
#  ('USA', 'Lovell Fld'): 208.0,
#  ('USA', 'Santa Fe Muni'): 1935.0,
#  ('CN', 'Kashi'): 1381.0,
#  ('N', 'Vaernes'): 17.0,
#  ('ET', 'Asyut International Airport'): 235.0,
#  ('GB', 'Birmingham'): 100.0,
#  ('S', 'Arlanda'): 42.0,
#  ('MK', 'Skopje'): 238.0,
#  ('IND', 'Jodhpur'): 219.0,
#  ('CH', 'EuroAirport Basel-Mulhouse-Freiburg'): 270.0,
#  ('RI', 'Tjilik Riwut'): 25.0,
#  ('E', 'La Gomera Airport'): 219.0,
#  ('RA', 'Comodoro Rivadavia'): 58.0,
#  ('CH', 'St Gallen Altenrhein'): 398.0,
#  ('RCA', 'Bangui M Poko'): 368.0,
#  ('USA', 'Bishop International'): 238.0,
#  ('PE', 'Teniente Alejandro Velasco Astete Intl'): 3311.0,
#  ('RM', 'Toliara'): 9.0,
#  ('CH', 'Geneva Cointrin'): 430.0,
#  ('UZB', 'Samarkand'): 678.0,
#  ('USA', 'Long Beach'): 18.0,
#  ('RO', 'Stefan Cel Mare'): 419.0,
#  ('I', 'Lampedusa'): 21.0,
#  ('BI', 'Bujumbura Intl'): 787.0,
#  ('I', 'Bergamo Orio Al Serio'): 238.0,
#  ('UA', 'Odesa Intl'): 52.0,
#  ('I', 'Parma'): 49.0,
#  ('E', 'Tenerife Norte'): 632.0,
#  ('CDN', 'Gander Intl'): 151.0,
#  ('R', 'Yelizovo'): 40.0,
#  ('F', 'Bellegarde'): 396.0,
#  ('LAO', 'Wattay Intl'): 172.0,
#  ('WAN', 'Mallam Aminu Intl'): 476.0,
#  ('GR', 'Eleftherios Venizelos Intl'): 94.0,
#  ('MEL', 'Melilla'): 48.0,
#  ('JOR', 'Queen Alia Intl'): 730.0,
#  ('AMSA', 'Pago Pago Intl'): 10.0,
#  ('EAK', 'Mombasa Moi Intl'): 61.0,
#  ('GR', 'Ikaria'): 24.0,
#  ('RI', 'Sultan Iskandarmuda'): 20.0,
#  ('DK', 'Esbjerg'): 30.0,
#  ('SA', 'King Khaled Intl'): 625.0,
#  ('GCA', 'La Aurora'): 1510.0,
#  ('C', 'Antonio Maceo Intl'): 76.0,
#  ('F', 'Provence'): 23.0,
#  ('DZ', 'Batna Airport'): 822.0,
#  ('SME', 'Johan A Pengel Intl'): 18.0,
#  ('USA', 'Minneapolis St Paul Intl'): 256.0,
#  ('DZ', 'Houari Boumediene'): 25.0,
#  ('COM', 'Prince Said Ibrahim'): 28.0,
#  ('N', 'Moss'): 53.0,
#  ('F', 'Orly'): 89.0,
#  ('E', 'La Palma'): 33.0,
#  ('WL', 'Hewanorra Intl'): 4.0,
#  ('AUS', 'Perth Intl'): 20.0,
#  ('THA', 'Nakhon Si Thammarat'): 4.0,
#  ('MOC', 'Pemba'): 101.0,
#  ('I', 'Rimini'): 13.0,
#  ('GBM', 'Isle Of Man'): 16.0,
#  ('BR', 'Afonso Pena'): 911.0,
#  ('TCH', 'Ndjamena Hassan Djamous'): 295.0,
#  ('AFG', 'Kabul Intl'): 1792.0,
#  ('USA', 'James M Cox Dayton Intl'): 308.0,
#  ('AXA', 'Wallblake'): 39.0,
#  ('CDN', 'Ottawa Macdonald Cartier Intl'): 114.0,
#  ('RI', 'Supadio'): 3.0,
#  ('VN', 'Noibai Intl'): 12.0,
#  ('CH', 'Lugano'): 279.0,
#  ('S', 'Kallax'): 20.0,
#  ('CN', 'Qiqihar Sanjiazi Airport'): 145.0,
#  ('R', 'Mukhino'): 515.0,
#  ('USA', 'Shreveport Rgnl'): 79.0,
#  ('RI', 'Sultan Mahmud Badaruddin Ii'): 15.0,
#  ('I', 'Firenze'): 43.0,
#  ('E', 'Salamanca'): 791.0,
#  ('S', 'Kristianstad'): 23.0,
#  ('BR', 'Marechal Cunha Machado Intl'): 54.0,
#  ('CN', 'Longdongbao'): 1139.0,
#  ('USA', 'Lanai'): 399.0,
#  ('ZRE', 'Mbuji Mayi'): 677.0,
#  ('USA', 'Chicago Ohare Intl'): 204.0,
#  ('BR', 'Augusto Severo'): 52.0,
#  ('R', 'Cherepovets Airport'): 115.0,
#  ('R', 'Grozny Airport'): 167.0,
#  ('BR', 'Santarem'): 60.0,
#  ('NCA', 'La Tontouta'): 16.0,
#  ('USA', 'Pierre Regional Airport'): 531.0,
#  ('USA', 'Norman Y Mineta San Jose Intl'): 19.0,
#  ('MOC', 'Quelimane'): 11.0,
#  ('USA', 'Dallas Fort Worth Intl'): 185.0,
#  ('DZ', 'Biskra'): 88.0,
#  ('LS', 'Moshoeshoe I Intl'): 1630.0,
#  ('MH', 'Marshall Islands Intl'): 2.0,
#  ('PA', 'Tocumen Intl'): 41.0,
#  ('WAN', 'Benin'): 79.0,
#  ('MNE', 'Podgorica'): 43.0,
#  ('BVIR', 'Terrance B Lettsome Intl'): 5.0,
#  ('RA', 'Presidente Peron'): 273.0,
#  ('E', 'Lanzarote'): 14.0,
#  ('CO', 'La Nubia'): 2095.0,
#  ('UAE', 'Sharjah Intl'): 34.0,
#  ('PK', 'Peshawar Intl'): 353.0,
#  ('CO', 'Alfonso Bonilla Aragon Intl'): 964.0,
#  ('TM', 'Ashgabat'): 211.0,
#  ('USA', 'Dane Co Rgnl Truax Fld'): 270.0,
#  ('D', 'Westerland Sylt'): 16.0,
#  ('CN', 'Gaoqi'): 18.0,
#  ('CDN', 'Hamilton'): 238.0,
#  ('R', 'Nalchik Airport'): 445.0,
#  ('USA', 'Cheyenne Rgnl Jerry Olson Fld'): 1877.0,
#  ('MEX', 'Tepic'): 921.0,
#  ('CN', 'Yinchuan'): 1098.0,
#  ('ROK', 'Yeosu'): 16.0,
#  ('CN', 'Xinzheng'): 151.0,
#  ('TN', 'Carthage'): 7.0,
#  ('KAZ', 'Kostanay West Airport'): 181.0,
#  ('IND', 'Lokpriya Gopinath Bordoloi International Airport'): 49.0,
#  ('MEX', 'C P A Carlos Rovirosa Intl'): 14.0,
#  ('PL', 'Balice'): 241.0,
#  ('CN', 'Yining Airport'): 666.0,
#  ('CR', 'Juan Santamaria Intl'): 921.0,
#  ('UAE', 'Al Ain International Airport'): 265.0,
#  ('E', 'Barcelona'): 4.0,
#  ('I', 'Venezia Tessera'): 2.0,
#  ('I', 'Bologna'): 38.0,
#  ('USA', 'El Paso Intl'): 1207.0,
#  ('D', u'Saarbr\xfccken'): 323.0,
#  ('WAN', 'Port Harcourt Intl'): 27.0,
#  ('USA', 'Sheppard Afb Wichita Falls Muni'): 311.0,
#  ('E', 'San Sebastian'): 5.0,
#  ('FGU', 'Rochambeau'): 8.0,
#  ('R', 'Vorkuta Airport'): 184.0,
#  ('KIR', 'Bonriki Intl'): 3.0,
#  ('USA', 'Baltimore Washington Intl'): 45.0,
#  ('USA', 'Rick Husband Amarillo Intl'): 1100.0,
#  ('R', 'Spichenkovo Airport'): 312.0,
#  ('YV', 'General Manuel Carlos Piar'): 144.0,
#  ('F', 'Nantes Atlantique'): 27.0,
#  ('KGZ', 'Manas'): 627.0,
#  ('IR', 'Bandar Abbas Intl'): 7.0,
#  ('USA', 'Mc Kellar Sipes Rgnl'): 132.0,
#  ('GB', 'Heathrow'): 25.0,
#  ('USA', 'Waco Rgnl'): 157.0,
#  ('USA', 'Bismarck Municipal Airport'): 506.0,
#  ('MEX', 'General Ignacio P Garcia Intl'): 191.0,
#  ('S', 'Vasteras'): 6.0,
#  ('TR', 'Sabiha Gokcen'): 95.0,
#  ('RI', 'Lombok International Airport'): 16.0,
#  ('A', 'Graz'): 340.0,
#  ('R', 'Belgorod International Airport'): 224.0,
#  ('H', 'Ferihegy'): 151.0,
#  ('VN', 'Cat Bi International Airport'): 2.0,
#  ('CN', 'Yanji Airport'): 190.0,
#  ('BR', 'Val De Cans Intl'): 16.0,
#  ('R', 'Novyi Urengoy'): 6.0,
#  ('RI', 'Pattimura'): 10.0,
#  ('IND', 'Bangalore'): 888.0,
#  ('R', 'Pulkovo'): 24.0,
#  ('S', 'Halmstad'): 31.0,
#  ('MEX', 'Licenciado Manuel Crescencio Rejon Int'): 12.0,
#  ('R', 'Petrozavodsk Airport'): 46.0,
#  ('CN', 'Zhanjiang Airport'): 38.0,
#  ('N', 'Flesland'): 52.0,
#  ('TUV', 'Funafuti International'): 3.0,
#  ('CN', 'Wujiaba'): 1895.0,
#  ('CN', 'Jining Airport '): 470.0,
#  ('RI', 'Wolter Monginsidi'): 164.0,
#  ('ANG', 'Lubango'): 1762.0,
#  ('IND', 'Jamnagar'): 21.0,
#  ('R', 'Koltsovo'): 233.0,
#  ('I', 'Linate'): 108.0,
#  ('RO', 'Cluj Napoca'): 316.0,
#  ('USA', 'Portland Intl'): 9.0,
#  ('MEX', 'General Rafael Buelna Intl'): 12.0,
#  ('WAN', 'Maiduguri'): 335.0,
#  ('RG', 'Conakry'): 22.0,
#  ('BDS', 'Grantley Adams Intl'): 52.0,
#  ('UA', 'Zhuliany Intl'): 179.0,
#  ('BG', 'Sofia'): 531.0,
#  ('RP', 'Legazpi'): 20.0,
#  ('BOL', 'Heroes Del Acre'): 272.0,
#  ('USA', 'Billings Logan International Airport'): 1113.0,
#  ('J', 'Fukuoka'): 10.0,
#  ('CN', 'Liangjiang'): 174.0,
#  ('MEX', 'Licenciado Benito Juarez Intl'): 2230.0,
#  ('GH', 'Kotoka Intl'): 63.0,
#  ('USA', 'Jacksonville Intl'): 9.0,
#  ('TR', 'Mus Airport'): 1267.0,
#  ('IR', 'Imam Khomeini'): 1008.0,
#  ('DZ', 'Ain Arnat Airport'): 1024.0,
#  ('GB', 'Norwich'): 36.0,
#  ('BR', 'Campo Dos Bugres'): 754.0,
#  ('P', 'Porto Santo'): 104.0,
#  ('FJI', 'Nausori Intl'): 5.0,
#  ('GB', 'Southend'): 15.0,
#  ('USA', 'Newark Liberty Intl'): 5.0,
#  ('THA', 'Chiang Mai Intl'): 316.0,
#  ('GB', 'Islay'): 17.0,
#  ('UAE', 'Dubai Intl'): 19.0,
#  ('KAZ', 'Almaty'): 681.0,
#  ('GR', 'Araxos'): 14.0,
#  ('BR', 'Pampulha Carlos Drummond De Andrade'): 789.0,
#  ('SA', 'Prince Mohammad Bin Abdulaziz'): 656.0,
#  ('R', 'Alykel'): 181.0,
#  ('UA', 'Osnova International Airport'): 155.0,
#  ('RP', 'Zamboanga Intl'): 10.0,
#  ('EW', 'Tallinn-Ulemiste International'): 40.0,
#  ('RM', 'Arrachart'): 114.0,
#  ('HR', 'Zadar'): 88.0,
#  ('S', 'Visby'): 50.0,
#  ('D', 'Dresden'): 230.0,
#  ('EC', 'Mariscal Sucre Intl'): 2813.0,
#  ('BR', 'Galeao Antonio Carlos Jobim'): 9.0,
#  ('NOK', 'Pyongyang Sunan Int'): 36.0,
#  ('I', 'Ciampino'): 130.0,
#  ('WAL', 'Freetown Lungi'): 26.0,
#  ('N', 'Aro'): 3.0,
#  ('BIH', 'Sarajevo'): 521.0,
#  ('MEX', 'Queretaro Intercontinental'): 1920.0,
#  ('R', 'Orenburg'): 118.0,
#  ('PY', 'Ciudad del Este'): 258.0,
#  ('MEX', 'Cancun Intl'): 6.0,
#  ('SP', 'Aden Adde International Airport'): 9.0,
#  ('I', 'Villafranca'): 73.0,
#  ('KAZ', 'Sary-Arka'): 538.0,
#  ('MAL', 'Kuching Intl'): 27.0,
#  ('RI', 'Sam Ratulangi'): 80.0,
#  ('KAZ', 'Atyrau'): -22.0,
#  ('BR', 'Zumbi Dos Palmares'): 118.0,
#  ('CN', 'Chaoyang Airport'): 173.0,
#  ('RA', 'Ushuaia Malvinas Argentinas'): 22.0,
#  ('CN', 'Aksu Airport'): 1163.0,
#  ('D', u'N\xfcrnberg'): 319.0,
#  ('IND', 'Rajkot'): 134.0,
#  ('ROK', 'Gwangju'): 12.0,
#  ('MEX', 'Don Miguel Hidalgo Y Costilla Intl'): 1529.0,
#  ('P', 'Corvo Airport'): 19.0,
#  ('D', 'Tegel'): 37.0,
#  ('RI', 'Jalaluddin'): 32.0,
#  ('USA', 'Abilene Rgnl'): 546.0,
#  ('YE', 'Taiz Intl'): 1475.0,
#  ('AUS', 'Townsville'): 5.0,
#  ('CN', 'Taiping'): 139.0,
#  ('R', 'Nizhnevartovsk'): 54.0,
#  ('R', 'Ignatyevo'): 195.0,
#  ('NORF', 'Norfolk Island Intl'): 113.0,
#  ('SGP', 'Changi Intl'): 7.0,
#  ('PK', 'Sialkot Airport'): 247.0,
#  ('RO', 'Satu Mare'): 123.0,
#  ('USA', 'Metropolitan Oakland Intl'): 3.0,
#  ('S', 'Bromma'): 14.0,
#  ('RSA', 'Pietersburg'): 1327.0,
#  ('BD', 'Zia Intl'): 9.0,
#  ('BOL', 'Juana Azurduy De Padilla'): 2905.0,
#  ('USA', 'Lambert St Louis Intl'): 188.0,
#  ('CO', 'Palonegro'): 1188.0,
#  ('R', 'Salekhard Airport'): 66.0,
#  ('IRQ', 'Sulaymaniyah International Airport'): 760.0,
#  ('VU', 'Port Vila Bauerfield'): 21.0,
#  ('RA', 'El Plumerillo'): 704.0,
#  ('F', 'Metz Nancy Lorraine'): 265.0,
#  ('USA', 'Alexandria Intl'): 27.0,
#  ('MOC', 'Inhambane'): 9.0,
#  ('CO', 'Rafael Nunez'): 1.0,
#  ('USA', 'Cincinnati Muni Lunken Fld'): 147.0,
#  ('AG', 'V C Bird Intl'): 19.0,
#  ('F', 'Biard'): 129.0,
#  ('USA', 'Cleveland Hopkins Intl'): 241.0,
#  ('CDN', 'Halifax Intl'): 145.0,
#  ('MEX', 'Ciudad Obregon Intl'): 63.0,
#  ('B', u'A\xe9roport de Li\xe8ge'): 201.0,
#  ('RMM', 'Senou'): 380.0,
#  ('SF', 'Mariehamn'): 5.0,
#  ('USA', 'Jackson Evers Intl'): 105.0,
#  ('MA', 'Menara'): 471.0,
#  ('SF', 'Lappeenranta'): 106.0,
#  ('MEX', 'General R Fierro Villalobos Intl'): 1360.0,
#  ('MNG', 'Chinggis Khaan Intl'): 1330.0,
#  ('GR', 'Kos'): 126.0,
#  ('IR', 'Tabriz Intl'): 1359.0,
#  ('RC', 'Kaohsiung Intl'): 9.0,
#  ('CDN', 'Edmonton Intl'): 723.0,
#  ('USA', 'Richmond Intl'): 51.0,
#  ('USA', 'Charleston Afb Intl'): 14.0,
#  ('R', 'Roschino'): 115.0,
#  ('NZ', 'Christchurch Intl'): 38.0,
#  ('TT', 'Piarco'): 18.0,
#  ('RA', 'San Luis'): 710.0,
#  ('EAT', 'Arusha'): 1387.0,
#  ('RP', 'Butuan'): 43.0,
#  ('USA', 'Savannah Hilton Head Intl'): 16.0,
#  ('J', 'Tottori'): 20.0,
#  ('XMAS', 'Christmas Island'): 279.0,
#  ('GR', 'Megas Alexandros Intl'): 5.0,
#  ('FARX', 'Vagar'): 85.0,
#  ('R', 'Sheremetyevo'): 190.0,
#  ('GNB', 'Osvaldo Vieira Intl'): 39.0,
#  ('RCH', 'Carlos Ibanez Del Campo Intl'): 42.0,
#  ('SF', 'Tampere Pirkkala'): 119.0,
#  ('MD', 'Chisinau Intl'): 122.0,
#  ('MYA', 'Yangon Intl'): 33.0,
#  ('R', 'Sokol'): 175.0,
#  ('J', 'Chubu Centrair Intl'): 5.0,
#  ('R', 'Balandino'): 234.0,
#  ('R', 'Pobedilovo Airport'): 146.0,
#  ('E', 'Barajas'): 610.0,
#  ('BR', 'Campo Grande'): 559.0,
#  ('USA', 'Syracuse Hancock Intl'): 128.0,
#  ('GR', 'Chios'): 5.0,
#  ('WSA', 'Hassan I Airport'): 63.0,
#  ('DZ', 'Noumerat'): 461.0,
#  ('RA', 'Santiago del Estero'): 200.0,
#  ('USA', 'General Edward Lawrence Logan Intl'): 6.0,
#  ('D', 'Dusseldorf'): 45.0,
#  ('IR', 'Abadan'): 6.0,
#  ('ROK', 'Jeju Intl'): 36.0,
#  ('CN', 'Hami Airport'): 824.0,
#  ('ANG', 'Cabinda'): 20.0,
#  ('R', 'Barnaul'): 255.0,
#  ('BR', 'Presidente Juscelino Kubitschek'): 1061.0,
#  ('RWA', 'Kigali Intl'): 1481.0,
#  ('RSA', 'Pietermaritzburg'): 739.0,
#  ('CZ', u'Brno-Tu\u0159any'): 235.0,
#  ('GB', 'Southampton'): 13.0,
#  ('E', 'Son Sant Joan'): 7.0,
#  ('CN', 'Phoenix International'): 28.0,
#  ('PL', 'Jasionka'): 206.0,
#  ('LAR', 'Benina'): 132.0,
#  ('MA', 'Mohammed V Intl'): 200.0,
#  ('EC', 'Mariscal Lamar'): 2532.0,
#  ('CN', 'Xining Caojiabao Airport'): 2170.0,
#  ('VIRG', 'Cyril E King'): 7.0,
#  ('TR', 'Erhac'): 862.0,
#  ('SN', 'Leopold Sedar Senghor Intl'): 26.0,
#  ('PK', 'Jinnah Intl'): 30.0,
#  ('CDN', 'Whitehorse Intl'): 706.0,
#  ('TR', 'Anadolu Airport'): 789.0,
#  ('CO', 'El Eden'): 1216.0,
#  ('ETH', 'Gondar'): 1994.0,
#  ('USA', 'Nantucket Mem'): 15.0,
#  ('DZ', 'Zenata'): 248.0,
#  ('BG', 'Varna'): 70.0,
#  ('USA', 'Kansas City Intl'): 313.0,
#  ('I', 'Catania Fontanarossa'): 12.0,
#  ('E', 'Zaragoza Ab'): 263.0,
#  ('CN', 'Capital Intl'): 35.0,
#  ('USA', 'Los Angeles Intl'): 38.0,
#  ('RO', 'Traian Vuia'): 106.0,
#  ('P', 'Lajes'): 55.0,
#  ('E', 'Ibiza'): 6.0,
#  ('SF', 'Rovaniemi'): 196.0,
#  ('RC', 'Sungshan'): 5.0,
#  ('NZ', 'Wellington Intl'): 13.0,
#  ('RA', 'La Rioja'): 438.0,
#  ('USA', 'General Mitchell Intl'): 220.0,
#  ('WAG', 'Banjul Intl'): 29.0,
#  ('R', 'Talagi'): 6.0,
#  ('J', 'Yamagata'): 108.0,
#  ('CN', 'Luoyang Airport'): 64.0,
#  ('MEX', 'Minatitlan'): 11.0,
#  ('J', 'Mt. Fuji Shizuoka Airport'): 132.0,
#  ('ZW', 'J M Nkomo Intl'): 1329.0,
#  ('IND', 'Chennai Intl'): 16.0,
#  ('E', 'Fuerteventura'): 25.0,
#  ('UZB', 'Termez Airport'): 313.0,
#  ('RI', 'Polonia'): 35.0,
#  ('IND', 'Lucknow'): 125.0,
#  ('SUD', 'Khartoum'): 386.0,
#  ('MOC', 'Lichinga'): 1373.0,
#  ('USA', 'San Diego Intl'): 5.0,
#  ('PL', 'Lech Walesa'): 149.0,
#  ('USA', 'Washington Dulles Intl'): 95.0,
#  ('WG', 'Point Salines Intl'): 13.0,
#  ('RI', 'El Tari'): 102.0,
#  ('CN', 'Xiaoshan'): 7.0,
#  ('HR', 'Zagreb'): 108.0,
#  ('R', 'Tolmachevo'): 111.0,
#  ('C', 'Ignacio Agramonte Intl'): 126.0,
#  ('USA', 'Toledo'): 209.0,
#  ('THA', 'Khon Kaen'): 204.0,
#  ('KAZ', 'Uralsk'): 38.0,
#  ('IR', 'Mashhad'): 995.0,
#  ('DK', 'Kastrup'): 5.0,
#  ('R', 'Novy'): 74.0,
#  ('AUS', 'Darwin Intl'): 31.0,
#  ('BOL', 'El Alto Intl'): 4063.0,
#  ('UA', 'Donetsk Intl'): 241.0,
#  ('THA', 'Samui'): 20.0,
#  ('NZ', 'Dunedin'): 1.0,
#  ('AUS', 'Cairns Intl'): 3.0,
#  ('DJI', 'Ambouli International Airport'): 15.0,
#  ('R', 'Emelyanovo'): 287.0,
#  ('BR', 'Santa Maria'): 7.0,
#  ('NL', 'Rotterdam'): -5.0,
#  ('D', u'L\xfcbeck'): 16.0,
#  ('ROU', 'Carrasco Intl'): 32.0,
#  ('R', 'Irkutsk'): 511.0,
#  ('USA', 'Greater Rochester Intl'): 170.0,
#  ('RIM', 'Nouakchott'): 2.0,
#  ('GUY', 'Cheddi Jagan Intl'): 29.0,
#  ('RP', 'Daniel Z Romualdez'): 3.0,
#  ('PY', 'Silvio Pettirossi Intl'): 89.0,
#  ('GE', 'Kopitnari'): 68.0,
#  ('PE', 'Cap Fap David Abenzur Rengifo Intl'): 156.0,
#  ('S', 'Landvetter'): 154.0,
#  ('RI', 'Syamsudin Noor'): 20.0,
#  ('CN', 'Jinan'): 23.0,
#  ('USA', 'Mahlon Sweet Fld'): 114.0,
#  ('S', u'\xd6stersund Airport'): 376.0,
#  ('RCH', 'Copiapo'): 305.0,
#  ('GB', 'Barra Airport'): 2.0,
#  ('USA', 'Wichita Mid Continent'): 406.0,
#  ('D', 'Baden Airpark'): 124.0,
#  ('RCH', 'Arturo Merino Benitez Intl'): 474.0,
#  ('CAYM', 'Owen Roberts Intl'): 2.0,
#  ('USA', 'Capital City'): 263.0,
#  ('GB', 'Exeter'): 31.0,
#  ('RI', 'Fatmawati Soekarno'): 15.0,
#  ('A', 'Innsbruck'): 581.0,
#  ('SK', 'M R Stefanik'): 133.0,
#  ('SF', 'Jyvaskyla'): 140.0,
#  ('RSA', 'Cape Town Intl'): 46.0,
#  ('A', 'Salzburg'): 430.0,
#  ('BR', 'General Leite de Castro Airport'): 684.0,
#  ('LV', 'Riga Intl'): 10.0,
#  ('I', 'Fiumicino'): 5.0,
#  ('BOL', 'Jorge Wilsterman'): 2549.0,
#  ('MA', 'Cherif El Idrissi'): 29.0,
#  ('PE', 'Coronel Carlos Ciriani Santa Rosa Intl'): 469.0,
#  ('DK', 'Aalborg'): 3.0,
#  ('C', 'Frank Pais Intl'): 110.0,
#  ('RA', 'Comandante Espora'): 75.0,
#  ('BR', 'Usiminas'): 239.0,
#  ('TR', 'Antalya'): 54.0,
#  ('N', 'Hammerfest Airport'): 244.0,
#  ('SF', 'Pori'): 13.0,
#  ('E', 'Tenerife Sur'): 64.0,
#  ('BR', 'Eduardo Gomes Intl'): 80.0,
#  ('A', 'Woerthersee International Airport'): 138.0,
#  ('MEX', 'General Pedro Jose Mendez Intl'): 232.0,
#  ('NAM', 'Windhoek Hosea Kutako International Airport '): 1720.0,
#  ('WD', 'Melville Hall'): 22.0,
#  ('ET', 'Borg El Arab Intl'): 54.0,
#  ('MEX', 'Quetzalcoatl Intl'): 148.0,
#  ('RI', 'Tabing'): 3.0,
#  ('P', 'Santa Maria'): 94.0,
#  ('RSA', 'Lanseria'): 1377.0,
#  ('KGZ', 'Osh'): 892.0,
#  ('R', 'Surgut'): 61.0,
#  ('ROK', 'Incheon Intl'): 7.0,
#  ('KAZ', 'Semipalatinsk'): 232.0,
#  ('R', 'Tambow'): 38.0,
#  ('SPMI', 'Saint-Pierre'): 8.0,
#  ('E', 'Bilbao'): 42.0,
#  ('RA', 'Teniente Benjamin Matienzo'): 456.0,
#  ('J', 'Hakodate'): 46.0,
#  ('RSA', 'East London'): 133.0,
#  ('EAT', 'Mtwara'): 113.0,
#  ('GE', 'Tbilisi'): 495.0,
#  ('IND', 'Hyderabad'): 531.0,
#  ('THA', 'Hat Yai Intl'): 27.0,
#  ('E', 'Valladolid'): 846.0,
#  ('AL', 'Tirana Rinas'): 38.0,
#  ('USA', 'Reno Tahoe Intl'): 1346.0,
#  ('CDN', 'Saskatoon J G Diefenbaker Intl'): 504.0,
#  ('IND', 'Madurai'): 140.0,
#  ('IND', 'Jammu'): 314.0,
#  ('WAN', 'Nnamdi Azikiwe Intl'): 342.0,
#  ('RO', 'Iasi'): 121.0,
#  ('USA', 'Lubbock Preston Smith Intl'): 1001.0,
#  ('ROK', 'Ulsan'): 14.0,
#  ('IRQ', 'Al Najaf International Airport'): 152.0,
#  ('USA', 'Fresno Yosemite Intl'): 102.0,
#  ('RCB', 'Pointe Noire'): 17.0,
#  ('KOS', 'Pristina'): 545.0,
#  ('TR', 'Diyarbakir'): 686.0,
#  ('MOC', 'Maputo'): 44.0,
#  ('MOC', 'Tete Chingodzi'): 160.0,
#  ('R', 'Khanty Mansiysk Airport'): 23.0,
#  ('E', 'Jerez'): 28.0,
#  ('CR', 'Daniel Oduber Quiros Intl'): 82.0,
#  ('MEX', 'Abraham Gonzalez Intl'): 1190.0,
#  ('B', 'Brussels Natl'): 56.0,
#  ('RP', 'Cotabato'): 58.0,
#  ('IND', 'Amritsar'): 230.0,
#  ('MEX', 'General Leobardo C Ruiz Intl'): 2177.0,
#  ('IND', 'Diu Airport'): 9.0,
#  ('CN', 'Lukou'): 15.0,
#  ('UZB', 'Urgench Airport'): 98.0,
#  ('S', 'Kronoberg'): 186.0,
#  ('BOL', 'Capitan Oriel Lea Plaza'): 1855.0,
#  ('RA', 'Corrientes'): 62.0,
#  ('TR', 'Cardak'): 852.0,
#  ('PR', 'Luis Munoz Marin Intl'): 3.0,
#  ('LAR', 'Misratah Airport'): 18.0,
#  ('SSD', 'Juba'): 461.0,
#  ('USA', 'Molokai'): 138.0,
#  ('RI', 'Juanda'): 3.0,
#  ('IND', 'Rajahmundry'): 46.0,
#  ('GB', 'Tiree'): 12.0,
#  ('CO', 'Camilo Daza'): 334.0,
#  ('RI', 'Achmad Yani'): 4.0,
#  ('R', 'Vnukovo'): 209.0,
#  ('USA', 'Baton Rouge Metro Ryan Fld'): 21.0,
#  ('CDN', 'Yellowknife'): 206.0,
#  ('TAD', 'Khudzhand Airport'): 442.0,
#  ('MEX', 'General Rodolfo Sanchez Taboada Intl'): 23.0,
#  ('BEN', 'Cadjehoun'): 6.0,
#  ('RP', 'Iloilo'): 8.0,
#  ('CO', 'Yariguies'): 126.0,
#  ('F', 'Blagnac'): 152.0,
#  ('RA', 'Ministro Pistarini'): 20.0,
#  ('USA', 'Nashville Intl'): 183.0,
#  ('IND', 'Aurangabad'): 583.0,
#  ('E', 'Vigo'): 261.0,
#  ('RSA', 'Bloemfontein Intl'): 1359.0,
#  ('BR', 'Leite Lopes'): 549.0,
#  ('DK', 'Bornholm Ronne'): 16.0,
#  ('D', 'Frankfurt Hahn'): 503.0,
#  ('USA', 'Phoenix Sky Harbor Intl'): 346.0,
#  ('BR', 'Amarais Airport'): 612.0,
#  ('USA', 'Port Columbus Intl'): 248.0,
#  ('R', 'Izhevsk Airport'): 162.0,
#  ('EAK', 'Malindi Airport'): 24.0,
#  ('RA', 'Aeroparque Jorge Newbery'): 5.0,
#  ('J', 'Nagasaki'): 5.0,
#  ('BG', 'Plovdiv'): 182.0,
#  ('S', u'\xd6rebro'): 57.0,
#  ('BR', 'Guararapes Gilberto Freyre Intl'): 10.0,
#  ('CN', 'Yichang Airport'): 205.0,
#  ('I', 'Elmas'): 4.0,
#  ('USA', 'Birmingham Intl'): 196.0,
#  ('F', 'Garons'): 94.0,
#  ('PL', 'Lodz Wladyslaw Reymont Airport'): 184.0,
#  ('IND', 'Vijayawada'): 25.0,
#  ('D', 'Paderborn Lippstadt'): 213.0,
#  ('CDN', 'St Johns Intl'): 141.0,
#  ('CAYM', 'Edward Bodden Airfield'): 1.0,
#  ('N', 'Geiteryggen'): 141.0,
#  ('RA', 'Jujuy'): 920.0,
#  ('ROK', 'Daegu Ab'): 35.0,
#  ('J', 'Narita Intl'): 43.0,
#  ('F', 'Guipavas'): 99.0,
#  ('R', 'Khomutovo'): 18.0,
#  ('RSA', 'Johannesburg Intl'): 1695.0,
#  ('IRQ', 'Baghdad International Airport'): 35.0,
#  ('HR', 'Rijeka'): 85.0,
#  ('CUR', 'Hato'): 9.0,
#  ('R', 'Yakutsk'): 99.0,
#  ('USA', 'Juneau Intl'): 6.0,
#  ('AZ', 'Heydar Aliyev'): 3.0,
#  ('CN', 'Hongqiao Intl'): 3.0,
#  ('B', 'Deurne'): 12.0,
#  ('CDN', 'Victoria Intl'): 19.0,
#  ('J', 'Matsuyama'): 8.0,
#  ('GB', 'Dundee'): 5.0,
#  ('TR', 'Esenboga'): 953.0,
#  ('PK', 'Chaklala'): 509.0,
#  ('IND', 'Raipur'): 317.0,
#  ('NIC', 'Managua Intl'): 59.0,
#  ('ROK', 'Gimhae Intl'): 2.0,
#  ('CV', 'Praia International Airport'): 70.0,
#  ('CN', 'Dongshan'): 661.0,
#  ('USA', 'Pittsburgh Intl'): 367.0,
#  ('CN', 'Huanghua'): 66.0,
#  ('IND', 'Coimbatore'): 404.0,
#  ('IRL', 'Dublin'): 74.0,
#  ('BRN', 'Bahrain Intl'): 2.0,
#  ('CN', 'Mudanjiang'): 269.0,
#  ('USA', 'Laredo Intl'): 155.0,
#  ('DZ', 'Soummam'): 6.0,
#  ('SK', 'Kosice'): 230.0,
#  ('USA', 'Mc Carran Intl'): 653.0,
#  ...}

# %%
df_river = pd.DataFrame(dict_river.items(), columns=['Country_ID_and_River', 'Length'])
df_river.sort(['Length'], ascending=False).head(10)
# Out:
#                 Country_ID_and_River  Length
# 116       (CO BR PE, river-Amazonas)    6448
# 13               (CN, river-Jangtse)    6380
# 217              (CN, river-Hwangho)    4845
# 159                  (R, river-Lena)    4400
# 176           (RCB ZRE, river-Zaire)    4374
# 183  (CN LAO THA K VN, river-Mekong)    4350
# 204        (R KAZ CN, river-Irtysch)    4248
# 73      (RMM RN WAN RG, river-Niger)    4184
# 133      (USA, river-Missouri_River)    4130
# 27               (R, river-Jenissej)    4092

# %%
df_lake = pd.DataFrame(dict_lake.items(), columns=['Country_ID_and_Lake', 'Area'])
df_lake.sort(['Area'], ascending=False).head(10)
# Out:
#                        Country_ID_and_Lake    Area
# 82   (R AZ KAZ IR TM, lake-KaspischesMeer)  386400
# 58           (CDN USA, lake-Lake_Superior)   82103
# 35         (EAT EAK EAU, lake-Victoriasee)   68870
# 49              (CDN USA, lake-Lake_Huron)   59600
# 43               (USA, lake-Lake_Michigan)   57800
# 129            (IL JOR WEST, lake-DeadSea)   41650
# 119     (ZRE Z BI EAT, lake-Tanganjikasee)   32893
# 0              (CDN, lake-Great_Bear_Lake)   31792
# 25                     (R, lake-Baikalsee)   31492
# 24               (MW MOC EAT, lake-Malawi)   29600

# %%
df_airport = pd.DataFrame(dict_airport.items(), columns=['Country_ID_and_Airport', 'Elevation'])
df_airport.sort(['Elevation'], ascending=False).head(10)
# Out:
#                                  Country_ID_and_Airport  Elevation
# 812                                 (BOL, El Alto Intl)       4063
# 54                                  (CN, Lhasa-Gonggar)       4005
# 24                                   (CN, Yushu Batang)       3963
# 1096                                      (PE, Juliaca)       3827
# 443        (PE, Teniente Alejandro Velasco Astete Intl)       3311
# 680                     (BOL, Juana Azurduy De Padilla)       2905
# 638                           (EC, Mariscal Sucre Intl)       2813
# 230           (PE, Coronel Fap Alfredo Mendivil Duarte)       2719
# 1188  (PE, Mayor General FAP Armando Revoredo Iglesi...       2677
# 1258         (MEX, Licenciado Adolfo Lopez Mateos Intl)       2581
